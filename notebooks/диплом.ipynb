# %%
# !pip install spacy bert-score tqdm
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.6)
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.3)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bert-score) (2.6.0+cu124)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from bert-score) (4.52.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.0.0->bert-score)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (0.31.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=3.0.0->bert-score) (0.5.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (3.2.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 10.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bert-score
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bert-score-0.3.13 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 128.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from huggingface_hub import login
login(token="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")

# %%
import spacy
from bert_score import score as bert_score
import numpy as np
import math
import json
from statistics import mean
from tqdm.auto import tqdm


nlp = spacy.load("en_core_web_sm")


def build_entity_grid(doc):
    """
    Строит решетку сущностей: строки — предложения, столбцы — сущности,
    ячейки — роль (S, O, -)
    Роль S — если сущность является подлежащим (упрощенно: первого по порядку токена), иначе O.
    """
    entities = []
    for ent in doc.ents:
        if ent.text not in entities:
            entities.append(ent.text)
    grid = []
    for sent in doc.sents:
        row = []
        first_token = sent[0].text
        for ent_text in entities:
            if ent_text in sent.text:
                if first_token in ent_text:
                    row.append('S')
                else:
                    row.append('O')
            else:
                row.append('-')
        grid.append(row)
    return grid


def cohere_score(grid):
    transitions = []
    for i in range(len(grid) - 1):
        for j in range(len(grid[0])):
            r1, r2 = grid[i][j], grid[i+1][j]
            if r1 != '-' and r2 != '-':
                transitions.append(math.log(1.0 + 1e-12))
    if not transitions:
        return float('-inf')
    return sum(transitions) / len(transitions)


def compute_cohere_score(context, generated):
    text = context + " " + generated
    doc = nlp(text)
    grid = build_entity_grid(doc)
    score = cohere_score(grid)
    return score / len(list(doc.sents))


def evaluate_dataset(path, desc="Dataset"):
    with open(path, 'r') as f:
        data = json.load(f)['rocstories']
    cs_list, bert_list = [], []
    for item in tqdm(data, desc=f"Evaluating {desc}", unit="item"):
        trg = item.get('TRG', '')
        sentences = [s.strip() for s in trg.split('.') if s.strip()]
        context = '. '.join(sentences[:4]) + '.'
        gen = item.get('GEN', '')
        # CohereScore
        cs_list.append(compute_cohere_score(context, gen))
        # BERTScore F1
        P, R, F1 = bert_score(
            [gen], [trg],
            lang='en',
            model_type='microsoft/deberta-v3-small',
            rescale_with_baseline=False,
            device='cpu'
        )
        bert_list.append(F1[0].item())
    return mean(cs_list), mean(bert_list)

full_path = '/content/150000-N=50-len=1.json'
light_path = '/content/10000-N=25-len=1.json'

full_cs, full_bert = evaluate_dataset(full_path, desc="Full (150k)")
light_cs, light_bert = evaluate_dataset(light_path, desc="Light (10k)")

print(f"\nМетрики для полного обучения (150k итераций):\n  CohereScore = {full_cs:.4f}, BERTScore F1 = {full_bert:.4f}")
print(f"\nМетрики для облегченного обучения (10k итераций):\n  CohereScore = {light_cs:.4f}, BERTScore F1 = {light_bert:.4f}")
# Out:
# Evaluating Full (150k):   0%|          | 0/5000 [00:00<?, ?item/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/286M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/286M [00:00<?, ?B/s]
# Evaluating Light (10k):   0%|          | 0/1000 [00:00<?, ?item/s]
# Метрики для полного обучения (150k итераций):
#   CohereScore = -inf, BERTScore F1 = 0.7209
#
# Метрики для облегченного обучения (10k итераций):
#   CohereScore = -inf, BERTScore F1 = 0.6996

# %%
import spacy
from bert_score import score as bert_score
import numpy as np
import math
import json
from statistics import mean
from tqdm.auto import tqdm

nlp = spacy.load("en_core_web_sm")


def build_entity_grid(doc):
    """
    Строит решетку сущностей: строки — предложения, столбцы — сущности,
    ячейки — роль (S, O, -)
    Роль S — если сущность является подлежащим (упрощенно: первого по порядку токена), иначе O.
    """
    entities = []
    for ent in doc.ents:
        if ent.text not in entities:
            entities.append(ent.text)
    grid = []
    for sent in doc.sents:
        row = []
        first_token = sent[0].text
        for ent_text in entities:
            if ent_text in sent.text:
                if first_token in ent_text:
                    row.append('S')
                else:
                    row.append('O')
            else:
                row.append('-')
        grid.append(row)
    return grid


def cohere_score(grid, allow_partial=False, partial_penalty=0.1):
    """
    Среднее лог-правдоподобие переходов сущностных ролей.
    Если allow_partial=True, учитываем переходы, где сущность присутствует хотя бы в одном предложении с штрафом.
    partial_penalty — вероятность для частичного совпадения.
    """
    transitions = []
    for i in range(len(grid) - 1):
        for j in range(len(grid[0])):
            r1, r2 = grid[i][j], grid[i+1][j]
            if r1 != '-' and r2 != '-':
                transitions.append(math.log(1.0 + 1e-12))
            elif allow_partial and (r1 != '-' or r2 != '-'):
                transitions.append(math.log(partial_penalty))
    if not transitions:
        return 0.0
    return sum(transitions) / len(transitions)

def compute_cohere_score(context, generated, allow_partial=False):
    text = context + " " + generated
    doc = nlp(text)
    print(f"Entities: {[ent.text for ent in doc.ents]}")
    grid = build_entity_grid(doc)
    score = cohere_score(grid, allow_partial=allow_partial)
    return score / len(list(doc.sents))

context = "Story sentence 1. Story sentence 2. Story sentence 3. Story sentence 4."
generated = "Proposed ending sentence."
cs = compute_cohere_score(context, generated, allow_partial=True)
print("CohereScore (partial):", cs)
# Out:
# Eval Full(150k):   0%|          | 0/5000 [00:00<?, ?it/s]
# Entities: ['Jill', '20 pounds', 'three months', 'James', 'James', 'James']
# Entities: ['Jim', 'three', 'Indiana', 'A year later', 'Joey', 'Cole', '1993']
# Entities: ['first']
# Entities: ['Jason', 'Jason', 'Jason']
# Entities: ['Mary', 'Rita', 'Gina', 'Bill', '20 years', 'Bill']
# Entities: ['Betsy', 'One', 'ten', 'one hour', 'months', 'Tim', 'Sunday', 'Serbian', 'Tim']
# Entities: ['Judy', 'Jason', 'many months', 'Jason', 'Jason']
# Entities: ['Bobby', 'F', 'Bobby', 'Bobby', 'Bobby', 'second', 'John', 'One', 'John']
# Entities: ['first', 'Tina', 'Tina', 'Tina']
# Entities: []
# Entities: ['David', 'David', 'the next two lengthy weeks', 'A week later', 'Fred']
# Entities: ['One day', 'one day']
# Entities: ['last summer', 'Jill', 'Jill', 'Jill', 'Jill']
# Entities: ['Barry', 'Barry', 'Anna', 'hours']
# Entities: ['this week', 'Jake', 'Hanna', 'Hanna']
# Entities: ['John', 'greenery', 'Joe', 'all day', 'Joe', 'that weekend']
# Entities: ['Nick', 'one day', 'Nick', 'Nick', 'Kyle', 'first', 'One day', 'Kurt', 'Craig', 'Craig']
# Entities: ['Chris', 'Lindsey', 'John', '200']
# Entities: ['John', 'the morning', 'the morning', 'John', 'the afternoon', 'John', 'all summer', 'One summer', 'John']
# Entities: ['Amy', 'Amy', 'a week ago']
# Entities: ['Judy', 'Sam', 'Sam']
# Entities: ['Amy', 'One', 'one', 'Amy', 'the end of the day', 'Amy', 'Raymond', 'Raymond', 'Raymond', 'Raymond']
# Entities: ['Jay', 'Jay', 'Jill', 'Jill', 'Jill']
# Entities: ['Katie', 'Constance', 'Suzy']
# Entities: ['Janice', 'Jeep', 'this weekend', 'Jeff', 'first', 'one hundred pounds', 'one day']
# Entities: []
# Entities: ['kittens', 'Kat', 'Tom', 'Tom', 'Tom', 'a week']
# Entities: ['George', 'first', 'George agreed', 'millions', 'Chris']
# Entities: ['one night', 'one day', 'Jake']
# Entities: ['India', 'Jack', 'Jack']
# Entities: ['Sam', 'Sam', 'Dexter', 'One day']
# Entities: ['Steve', 'one year', 'Kelsi', 'Kelsi']
# Entities: ['Seth', 'John', 'the day', 'John', 'John']
# Entities: ['seven', 'Jill', 'early one morning', 'Panther', 'Sanbucks']
# Entities: ['Tim', 'Alice', 'one day']
# Entities: ["Candy Cane's", 'Candy Cane', 'Christine', 'Christine', 'Dexter', '2 weeks']
# Entities: ['Tom']
# Entities: ['Carl', 'one', 'John', 'a bad day', 'John', 'John']
# Entities: ['Dan', "Joker's Wild", 'Dan', "Joker's Wild", 'Dan', 'Dan', 'Dan', 'Joker', 'Lucy', 'Lucy', 'Lucy']
# Entities: ['Jane', 'Jane', 'three hours']
# Entities: ['first', '10 minutes']
# Entities: ['Jill']
# Entities: ['Coco', 'Coco', 'every morning', 'daily', 'weeks', 'second']
# Entities: ['that morning']
# Entities: ['Joe', 'three hours', 'first']
# Entities: ['Tom', 'the winter', 'first', 'Pamela', 'first', 'the year', 'Paula']
# Entities: ['Tim', 'One day', 'five hours', 'Hannah', '8 years old', 'Hannah']
# Entities: ['Greta', 'months', 'the day', 'One', 'Hanna']
# Entities: ['Ben', 'John', 'one morning', 'John', 'John', 'John', 'John']
# Entities: ['Kelly', 'Kelley', 'Tim', 'all day', 'One day']
# Entities: ['Stassi', 'Los Angeles', 'Stassi', 'New York', 'Stassi', 'Mary', 'Mary']
# Entities: ['several miles', 'Mark', 'Mark']
# Entities: ['Last night', 'Erich', 'Max', 'less than 5 minutes']
# Entities: ['Drake']
# Entities: ['Sue', 'one morning', 'all night']
# Entities: ['Bill', 'Aruba', 'New Years', 'Bill', 'Sue']
# Entities: ['Sam', 'tonight']
# Entities: ['Blair', 'Anna', 'Anna']
# Entities: ['Kate', 'just 20 minutes', 'Kate', 'Tim']
# Entities: ['Grady', 'Joe', 'a very hot day']
# Entities: ['Casey', 'Casey', 'Casey', 'Casey']
# Entities: ['Erin', 'Friday', 'all week', 'all night', 'Thursday', 'Bill', 'Bill', 'Bill', 'Bill', 'Bill', 'Bill', 'Bill', 'Bill']
# Entities: ['Merrill', 'Garcia', 'one morning', 'Eugene']
# Entities: ['Rufus', 'a dozen', 'Rufus', 'Lucy', 'Lucy', 'Lucy']
# Entities: ['couple minutes later', 'Jane', 'Grandma', 'Jane', 'Jane', 'Jane']
# Entities: ['one', 'One day', '5 years', 'Carlos']
# Entities: ['Kelly', 'tenth', 'Kelly']
# Entities: ['10', 'John', 'John']
# Entities: ['Jen', 'one day']
# Entities: ['3', 'Andy', 'Boston', 'Andy', 'Boston', 'December', 'Andy', 'Andy']
# Entities: ['Molly', 'Sally', 'Sunday', 'Sally']
# Entities: ['every day', 'a week', 'Allie', 'Allie']
# Entities: ['Christian', 'Christian', 'Sally', 'Sally']
# Entities: ['Jeff', 'over two feet', 'Jeff', 'Charles', 'Charles', 'Charles']
# Entities: ['Walter', 'Walter', 'Walter']
# Entities: ['Jim', 'four minutes']
# Entities: ['Paul', 'Paul', 'Veteran', 'One']
# Entities: ['Alex', 'Alex', 'Alex', 'Sue']
# Entities: ['Mary', 'the long hours', 'Mary', 'Ed', 'Ed']
# Entities: ['Japanese', 'Chinese', 'One', 'Chinese']
# Entities: ['Paul', 'Paul', 'first', 'Paul', 'Tim', 'Tim', 'Tim']
# Entities: ['Randy', 'Last week', 'Randy', 'Jane', 'Jane', 'Jane']
# Entities: ['Tom', 'Tom', 'Tom']
# Entities: ['Shannon', 'Tom', 'Florida', 'One day', 'Christmas', 'Tom']
# Entities: ['Beth']
# Entities: ['One', 'one', 'Meg', '21', '5', '7', 'three years later', '45']
# Entities: ['Tyler', 'Nicholas', 'One day', '1700']
# Entities: ['Stacey', 'Tim', 'One day', 'Tim']
# Entities: ['Jill', 'Jill']
# Entities: ['Alex', 'Alex', 'Alex', 'Tim', 'One day', 'Tim', 'Tim']
# Entities: ['Joanie', 'Joanie', 'Jake', 'a few days', 'Jake']
# Entities: ['Erin', 'next semester', 'Anna', 'Anna', 'Anna']
# Entities: ['Sam', 'Ikea', 'Sam', 'Tom', 'Tom', 'an hour', 'Tom', 'the end of the day', 'Tom']
# Entities: ['Kevin', 'Glenn', 'Joe', 'Joe']
# Entities: ['Tammy', 'one morning', 'Amy', '3 Years', 'Cadillac']
# Entities: ['One day', 'Kate', 'the day', 'Kate']
# Entities: ['John', 'Home Depot', 'Saturday', 'morning', 'John', 'Tim']
# Entities: ['Bella', 'One day', 'Bella', 'Bella', 'Jim', '95']
# Entities: ['Lorpen Lapp', 'Sam']
# Entities: ['Mark']
# Entities: ['Gary', 'Gary', 'every single minute']
# Entities: ['Danny', 'one', 'Beth', 'Beth', 'Danny', 'one day']
# Entities: ['Kay', 'Jim', 'Jim', 'every day', 'a month later', 'Jim', 'every day']
# Entities: ['Sam']
# Entities: ['Josh', 'Josh', 'Josh', 'Shelly']
# Entities: ['Sam', 'Sam', 'Sam']
# Entities: ['Tom', 'Tom', 'Tom']
# Entities: ['Ray', 'two', 'Ray', 'Ray', 'Ray', '2', '1', 'Hanna']
# Entities: ['Barbie', 'another six months']
# Entities: ['Mark', 'recycle day', 'John', '16']
# Entities: ['Jim', 'the night', 'the day', 'Mark', '4 years old', 'One day', 'Tang', 'Mark', 'Mark']
# Entities: ['Yesterday']
# Entities: ['Tim', 'last day', 'Kate', 'one weekend', 'Kate', 'Kate']
# Entities: ['Spike', 'six', 'six', '90 minutes', 'eighth', 'Lucy', 'two months ago', 'a few months', 'Lucy']
# Entities: ['Jim', 'monday', 'the day', 'Jim', 'first', 'the age 60 years ago', 'Canadian', '10th', 'a year']
# Entities: ['Mary', 'Shelley', 'Mary', 'Mary', 'Allie', 'Harvard', 'Allie']
# Entities: ['2013', '20 years', 'Stanley', 'a few minutes']
# Entities: ['Thomas', 'One day', 'Thomas', '#', '30 minutes']
# Entities: ['Denis', 'Connie', 'the end of day']
# Entities: ['James', 'the next day']
# Entities: ['Bill', 'Bill', 'Kyle', 'Bill', 'Elton', 'ten']
# Entities: ['Carson', 'Carson']
# Entities: ['Jim', 'Jim', 'Jim', 'Jim']
# Entities: ['Jim', 'One', 'night', 'Tom', 'Tom']
# Entities: ['Tom', 'Tom', 'Tom', 'twelve hours']
# Entities: ['Yesterday']
# Entities: ['ten', 'Sue']
# Entities: ['Robbie', 'Oklahoma', 'Japan', 'One day', 'Japan', 'Angelo']
# Entities: ['Lily', 'Kim', 'Hispanic', 'Kim', 'two months', 'An hour later', 'Mexico']
# Entities: ['Lilly', 'every minute', 'several days']
# Entities: ['three', 'Ten hours later']
# Entities: ['Ali', 'Jerry', 'Jerry', 'Jerry', 'Jerry']
# Entities: ['Marcus', 'Bob', 'Bob', 'Bob', 'Bob', 'the next day']
# Entities: ['Bill', 'One']
# Entities: ['Natalie']
# Entities: ['Jerry', 'One day', 'James', 'half', 'James']
# Entities: ['One day']
# Entities: ['Zach', 'yesterday', 'Abby', 'her first day', 'Abby', 'Abby']
# Entities: ['Tina', 'the class One day', 'Fred', 'Fred', 'Fred']
# Entities: ['Sam', 'sam', 'Sam', 'Tina', 'half', 'Tina']
# Entities: ['Larry', 'one day', 'Larry', 'Tim', 'Tim']
# Entities: ['Bill', 'Today', 'Bill', 'Bill', 'Bill', 'teddy ball', 'One day']
# Entities: ['Bill', 'Bill', 'about 30 cents']
# Entities: []
# Entities: ['XBox', 'Cathy', 'Cathy']
# Entities: ['Tom', 'Kate']
# Entities: ['Anger', 'Sam', 'Sam']
# Entities: []
# Entities: ['Allie']
# Entities: ['Stewart', '25', 'one', 'Kia', 'Kia']
# Entities: ['Frida', 'Today', 'Frita', 'Anna', 'noon', 'Anna']
# Entities: ['a weekend', 'hours', 'Lucy', 'tomorrow', 'all night', 'Lucy', 'the last minute', 'Lucy']
# Entities: ['Dina', 'Portland', 'one morning', 'Date']
# Entities: ['Kevin', 'Kevin', 'Kevin', 'Fred', 'four hundred', 'Fred']
# Entities: ['Brandon', 'Anthony', 'Brandon', 'Brandon', 'Brandon', 'Kelly', 'five months', 'Kelly']
# Entities: ['Kim', 'Kim', 'Kia', 'seven', 'one night', 'Three', 'Kia']
# Entities: ['every day', 'a couple hours', 'each day', 'Kim', 'ten', 'Kim', 'Kim', 'Kim']
# Entities: ['Taylor', 'Nicholas', 'every day']
# Entities: ['one summer day', 'Tom', 'Tom', 'twenty']
# Entities: ['Kate', 'Kate', '15 minutes', 'Tina', 'Tina', 'three hours', 'Tina']
# Entities: ['Debbie', 'last week', 'the other day', 'Marc']
# Entities: ['Trisha', '9th', 'this year', 'a month', 'Jane', 'Jane']
# Entities: ['every day', 'One day', 'Kim', 'ten', 'Kim', 'five hundred dollars', 'Kim', 'one hundred dollars', 'ten']
# Entities: ['Anna', 'New York', 'English', 'French', 'French']
# Entities: ['One', 'Seth', 'a week', 'Claude', 'Seth']
# Entities: ['Eight year old', 'Barry', 'Barry', 'first', 'Mars', 'Lucy', 'fifth', 'all day', 'her first day', 'that day']
# Entities: ['Saturday', 'Erin', 'New York', 'New York', 'half']
# Entities: ['Jim', 'One day', 'Tim', 'months', 'Tim']
# Entities: ['Sam', 'the weekend', 'Kia', 'Christmas', 'Kia']
# Entities: ['Tim', 'two years old', 'Tim', 'Tim', 'Tim']
# Entities: ['Mortimer', 'Tim', 'Tim']
# Entities: ['Tom']
# Entities: ['last night', 'Diesel', 'the 1950s', 'James', 'first', 'James', 'James']
# Entities: ['first', 'The first day', 'the new year', 'Milde', '5 years']
# Entities: ['two', 'Julia']
# Entities: ['a few hours', 'Jack', 'The next morning', 'Jack', 'Jack']
# Entities: ['One day', 'Bob', 'two', 'four', 'Bob']
# Entities: ['Amy', 'Steve', 'three', 'Steve', 'one', 'Steve', 'Steve', 'Steve', 'Steve', 'Steve', 'Jason', 'Steve']
# Entities: ['Kim', 'Kim', 'Kim']
# Entities: ['Susan', 'Susan', 'four', 'six - five']
# Entities: ['John', 'John', 'John', 'Bob', 'second', 'Bob']
# Entities: ['Tom', 'days']
# Entities: ['Lolita', 'Gina', 'Lolita', 'Gina', 'Jim', 'Jim', 'Jim', 'Jim']
# Entities: ['Sue', 'Sue', 'The next day']
# Entities: ['Jill', 'Jill', 'Jill', 'Tim']
# Entities: ['One day', 'Tim', 'Tim']
# Entities: ['Vicki', 'Jason']
# Entities: ['Tom', 'Tom', 'Tim', 'Tim', 'Tim']
# Entities: ['Rufus', 'English', 'Rufus', 'all day', 'One day']
# Entities: ['Kurt', 'Sam', 'Sam', 'Sam', 'Sam', 'Sam']
# Entities: ['Tom', 'Kia', 'Kia', 'Kia', 'Kia']
# Entities: ['Harry', 'one night', 'Harry', 'Tim', 'Tim']
# Entities: ['Matt', 'Anna', 'winter', 'all spring', 'one day', 'Monday']
# Entities: ['John', 'Amy', 'Amy', 'Amy']
# Entities: ['Superman', 'Lucy', 'twenty years old']
# Entities: ['Tina', 'Tina', 'Lucy', 'Lucy']
# Entities: ['Riley', 'BB', 'Christmas day']
# Entities: ['Terry', 'a day', 'Gary', 'Gary', 'Gary']
# Entities: ['One day', 'Kim', 'last month', 'ten years', 'Kim', 'first']
# Entities: ['Tom', 'Tom']
# Entities: ['Benny', 'One day']
# Entities: ['Craigslist']
# Entities: ['one day', 'Philip', 'Rob', 'Rob']
# Entities: ['Taylor', 'Taylor', 'Tim', 'a week', 'a week', 'The day', 'two']
# Entities: ['Sam', 'Sam', 'Christmas', 'Sam']
# Entities: ['Joan', 'Eli', 'Eli', 'Joan', 'Trinidad', 'Christmas', 'first', 'Christmas', 'Charles', 'that year']
# Entities: ['The Blue Dahlia', 'ten years ago', 'This month', 'Mary', 'Mary', '100']
# Entities: ['Tom', 'years', 'Charles', 'Every week', 'one', 'Charles']
# Entities: ['Rashid', 'Isis', 'Rashid', 'Rashid', 'Ed']
# Entities: ['the next 20 minutes']
# Entities: ['Kia', "6 Year's old", 'the next day', 'one', 'Runny', 'Brandon', 'one day']
# Entities: ['Tom', 'Tom']
# Entities: ['French', 'France']
# Entities: ['almost a year', 'Christmas', 'One day']
# Entities: ['1 AM', 'Lisa', 'Tina', 'Tina']
# Entities: ['Kim', 'Tim', 'Kim', 'the Ferris Wheel', 'Tim', 'Kim', 'Mary', 'Mary']
# Entities: []
# Entities: ['Karen', 'two days', 'One day', 'Kim', 'Kim', 'Kim']
# Entities: ['Bobby', 'Andrew', 'thousands', 'Andrew']
# Entities: ['Ethan']
# Entities: ['Sam', 'Sam', 'Sam']
# Entities: ['Mike', 'Allie', 'Allie']
# Entities: ['Jason', 'Roy']
# Entities: ['Kaurn', 'that year', 'Kaurna', 'next year', 'Kaarne']
# Entities: ['Flora', 'Flora', 'Jane', 'Tom', 'Jane', 'Jane']
# Entities: ['Bob', 'Kelly', 'Kelly', 'Kelly']
# Entities: ['Joe', 'One day', 'Joe', 'Joe', 'Tim', 'second', '20', 'second']
# Entities: ['last night', 'Tim', 'Tim']
# Entities: ['Amy', 'Bath and Body Works', 'Amy', 'Amy', 'a full 8 hour', 'Allie']
# Entities: ['Sue', 'a really bad day', 'Sue']
# Entities: ['Sean', 'Sara', 'Jim', 'Jim']
# Entities: ['Evan', 'April', 'first', 'April', 'Ted', 'Ted', 'Ted']
# Entities: ['Ali', 'Ali', 'Ali', 'Kate', 'tonight', 'Kate', 'Kate']
# Entities: ['Barry', 'One day', 'the year', 'that year', 'the end of the year Jake', 'that year']
# Entities: ['James', 'One day']
# Entities: ['Aaron', 'Friday']
# Entities: ['One day', 'Rachelle', '911', 'Tim', 'days']
# Entities: ['Fred']
# Entities: ['Bill', 'Shakespeare', 'the summer', 'summer', 'Hamlet']
# Entities: ['Danny', 'first', 'Danny', 'Danny', 'first', 'Danny', 'Joe', 'Joe', 'Joe']
# Entities: ['Anna', 'late at night', 'Anna']
# Entities: ['One day', 'Jackson', 'Chinese', 'Tim', 'Tim', 'Tim']
# Entities: ['Nita', 'Lucy', 'Lucy', 'Lucy', 'Lucy', 'Lucy']
# Entities: ['One night', 'Dan', 'Chinese', 'Dan', 'Dan', 'Dan', 'one']
# Entities: ['Amy', 'Ben', 'Joe', 'many years', 'Joe']
# Entities: ['Bob', '$ 50', 'Bill', 'The next day', 'Sam', 'Sam', 'Sam']
# Entities: ['Ella', 'sixteenth', 'Ella', 'a few months', 'a few weeks', 'Ella', 'Fran', 'Fran']
# Entities: ['Tom', 'Tom', 'Smith', 'every day', 'One day']
# Entities: ['Tony', 'Tom', 'Tom', 'the end of the day']
# Entities: ['Sally', 'Sally', 'Fred', 'Sally', 'Sally', '5th', 'July']
# Entities: ['Portia', 'fifteen', 'Today', 'the day']
# Entities: ['Jane', 'Christmas', 'Saturday', 'Jane']
# Entities: ['Jessica', 'Jessica', 'Jessica', 'Jack', 'months', 'Jack', 'Jack', 'Jack']
# Entities: ['Carla', 'sixth', 'Carla', 'Carla', 'Jenny', 'Jenny', 'Jenny']
# Entities: ['Charles', 'two', 'Charles', 'three', 'all day']
# Entities: ['Jennifer', 'John', 'United', 'English', 'a week', 'John', 'American']
# Entities: ['Cole', 'Santa', 'Christmas Eve', 'midnight', 'Santa', 'Cole', 'Jill', 'Jill']
# Entities: ['three days', 'Chris', 'One day', 'Chris', 'Chris', 'Chris', 'Indonesia']
# Entities: ['Dan', 'Dan']
# Entities: ['New York City', 'Broadway', 'Melissa']
# Entities: ['Larry', 'two', 'Larry', 'Larry', 'One day', 'Larry', 'Carlos', 'first', 'Gabrielle']
# Entities: ['Jane', 'Paris', 'first', 'India', 'Madagascar', 'One day', 'this day']
# Entities: ['Jesus']
# Entities: ['2', 'Sam', 'Sam']
# Entities: ['one morning']
# Entities: ['Jane', 'Anna', 'Jane', 'Andy', 'every night', 'Andy', 'Andy', 'Friday', 'night', 'Andy']
# Entities: ['night']
# Entities: ['Mike', 'Mike', 'Mike', 'Jake']
# Entities: ['Kate', 'Minnesota', 'three months', 'Brandon', 'Jonathan']
# Entities: ['Emma', 'first day', 'Emma', 'Emma', 'Tim', 'One', 'Tim']
# Entities: ['Katherine', 'July', 'the day', 'Katherine', 'Bob', 'one', 'the next year', 'Bob', 'Bob', 'the United States']
# Entities: ['Toby', 'Fred']
# Entities: ['Tim', 'Sally']
# Entities: ['Ashley', 'Jessica', 'Ashley', 'Jessica', 'Jessica', 'A few minutes later', 'the day']
# Entities: ['Ella', 'Tina', 'Tina', '3', '19', 'Tina', 'Tina', 'Tina', 'Tina', 'Tina']
# Entities: ['Jake']
# Entities: ['Brandon', 'Charles', 'Brandon', 'Tom', 'Tom']
# Entities: ['Vicky', 'Vicky', 'Kenny', 'six']
# Entities: ['Charles']
# Entities: ['Lucy', 'her first day', 'an hour', 'a few days', 'Lucy']
# Entities: ['Jane', 'Jane', 'Lucy', 'Lucy', 'Lucy', 'Lucy']
# Entities: []
# Entities: ['Larry', 'first', 'first', 'Lawrence', '10']
# Entities: ['Charles', 'Charles', 'Mary', 'Mary']
# Entities: ['John', 'Tuesday', 'all weekend', 'Sunday', 'evening', 'John', 'Wednesday', 'John', 'Chloe']
# Entities: ['Jeff', 'Anna', 'a nice afternoon', 'Anna']
# Entities: ['Sandra', 'Today']
# Entities: ['Jesse', 'Tom', 'Tom']
# Entities: ['Chase', 'Chase', 'Chase', 'Sam', 'noon', 'Sam']
# Entities: ['Last week', 'This week', 'late at night', 'James', 'one night', 'half an hour']
# Entities: ['Sam', 'Sam', 'Sam', 'The next day']
# Entities: ['one day', 'Sam']
# Entities: ['Jason', 'many weeks', 'Bob', '5 Years', 'Bob']
# Entities: ['Carl', 'Mary', 'Carl', 'Mary', 'Carl', 'second', 'a year', 'Mary', 'Shirley']
# Entities: ['Katie', 'Katie', 'Tom', 'two', 'Tom', 'Tom']
# Entities: ['Henry', 'four - year old', 'Henry', 'Julia', 'Henry', 'Julia', 'Henry', 'Anna', 'Anna']
# Entities: ['Jen', 'Mike', 'Al']
# Entities: ['Aya', 'first', 'first', 'Japan', 'first', 'Jeff', 'Jeff', 'the day', 'Jeff']
# Entities: ['seven years old', 'Tom', 'five years ago', '20']
# Entities: ['Andrew', 'the past two months', 'at least an hour', 'Andrew', 'Abby', 'Abby', 'a few months', 'Abby', 'Abby']
# Entities: ['One day', 'Tegger']
# Entities: ['Ray', '5 minutes later', 'Tim', 'Tim', 'Tim', 'all night', 'Tim']
# Entities: ['1983', 'Christmas', 'Florida', 'One summer']
# Entities: ['one', 'Allie', 'Allie']
# Entities: ['first', 'first', 'one morning', 'Anna']
# Entities: ['Jenna', 'Jenna', 'Mark']
# Entities: ['Jessie', 'One day', 'Jessie', 'Eric', 'Mexican']
# Entities: ['Sam', 'Sam']
# Entities: ['April Fools', 'eBay', 'Sue', 'Sue', 'her senior year']
# Entities: ['Jen', 'One day', 'Tom', 'Half', 'Tom']
# Entities: ['nine', 'Amy', 'Amy', 'Amy', 'Amy']
# Entities: ['Rick', '10']
# Entities: ['Georgia', 'a few weeks ago', 'Denver', 'Atlanta', 'Atlanta', 'Savannah', 'Savannah', 'Atlanta', 'Tom']
# Entities: ['Melinda', 'first', '20 years', 'One day']
# Entities: ['John', 'John', 'John']
# Entities: ['one', 'Kelly', 'first', 'Kelly']
# Entities: ['Gary', 'Gary', 'one night']
# Entities: ['Josh', 'John', 'John']
# Entities: ['One']
# Entities: ['Max', 'Disneyland', 'three hour', 'seconds', 'Gary', 'One morning', 'Kenny']
# Entities: ['Paul', 'Valentine', 'One']
# Entities: ['Amy', 'the summer', 'Amy', 'the last day', 'one day', 'Kayla', 'Kayla']
# Entities: ['first', 'Kate']
# Entities: ['Tim', 'Tim', 'Command', 'The next year', 'Richard', 'Phillies']
# Entities: ['One', 'LA', 'First', 'Universal Studios', 'Griffith Park', 'Disneyland', 'Jesse', 'a few weeks']
# Entities: ['James', 'One day', 'James', 'hours a week', 'the day', 'James', 'James']
# Entities: ['Tim', 'first day', '30 dollars', 'Tim', 'that week', 'One']
# Entities: ['Dotty', 'Dotty', 'Mary', 'three', 'first', 'Mary']
# Entities: ['all day', 'Nadia']
# Entities: ['Breakfast', 'Tina', 'thousands', 'Tina']
# Entities: ['Steve', 'Steve', 'Halle', 'Beth', 'Jake', 'Jake', 'Beth', 'next week']
# Entities: ['Tim', 'James', 'One day', 'James']
# Entities: ['Tom', 'Tom', 'second', 'Spencer', 'Ali', 'five', 'five']
# Entities: ['Karen', 'half', 'two hours', 'Karen', 'past midnight', 'Cindy', 'weeks']
# Entities: ['Mark', 'first', 'Tila', 'Sam', 'Tila', 'Tila', 'Tila', 'Sam']
# Entities: ['Tom', 'all day', 'Tom', 'Jane', '238', 'Jane']
# Entities: ['Bob', 'Oklahoma', 'Dad', 'Bob', 'two miles', 'Bob', 'Mary', 'a little little sea bird', 'Mary', 'Sam']
# Entities: ['mike', 'Kim', 'Kim', 'every few months']
# Entities: ['Barry', 'Barry', 'Barry', 'Barry', 'Toyota', 'Sarah']
# Entities: ['Fjord', 'norwegian', 'years ago']
# Entities: ['Constance', '5']
# Entities: ['The first day', 'years']
# Entities: ['Jeff', 'dozens', 'One day', 'This year']
# Entities: ['Bill', 'Lansing', 'Bill', '5 inches', 'an hour', 'Bill', '2 hours', 'Lansing', 'Sally', 'First', 'an hour']
# Entities: ['Neil', 'India', 'Dexter', 'Dave']
# Entities: ['Kalani', '10 years old', 'Kalani', '18', 'Jenna', 'all year', 'this year', 'this year', 'Jenna']
# Entities: ['Sam', 'Hallish', 'noon', 'Sam']
# Entities: ['Alice', 'Maria', 'One day', 'Alice', 'Maria', 'the afternoon', 'Maria', 'Alice', 'Sam', 'every day', 'one day']
# Entities: ['Jimmy', '50', 'Jesus', 'Wendy']
# Entities: ['4 hours', 'a half hour', '5']
# Entities: ['Tim', 'Tim', 'four', 'Horace', 'Horace', 'Horace']
# Entities: ['Samuel', 'Las Vegas', 'last weekend', 'Mike', 'daily', 'Mike', 'Mike', 'several hours']
# Entities: ['Matt', 'Joe', 'that day', 'Joe']
# Entities: ['Alana', 'Australia', 'first', 'Oregon', 'Jeff', 'a few Years', 'Jeff', 'the last minute']
# Entities: ['Jane', 'today', 'Jane', 'Gary']
# Entities: ['Disney World', 'a ton', 'Disney', 'Daniel', 'Dad', 'Dad', 'the day']
# Entities: ['Charlie', 'Charlie', 'all day', 'a couple of months', 'Charlie', 'Charlie', 'Charlie', 'John', 'a month', 'John']
# Entities: ['Hair', 'Las Vegas', 'Ike']
# Entities: ['Greg', 'dozens', 'every day', 'Greg', 'Tom', 'Tom', 'Tom', 'Amazon', 'Tom', 'Tom']
# Entities: ['One', 'first', 'many years', 'first']
# Entities: ['Cindy', 'Cindy', 'Cindy']
# Entities: []
# Entities: ['Reggie', 'Reggie', 'Iraq', 'Iraq', 'Reggie', 'Reggie', '19', 'Iraq', 'Lawrence', 'next day', 'half an hour', 'the day']
# Entities: ['almost every day', 'Bob', 'Eventually Bob']
# Entities: ['Matty', 'Every day', 'One day', 'Sally', 'Sally', 'Sally']
# Entities: ['4', 'Jake', 'all summer']
# Entities: ['Glen', 'Glen']
# Entities: ['Craig', 'months', 'a few weeks', 'Gary', 'Gary', 'Stan']
# Entities: ['John', 'One day', 'Kelly', 'Kelly']
# Entities: ['Bob', 'Sam', 'Sam', 'Sam']
# Entities: ['Charles', '8th', 'Charles', 'the day', 'Charles', 'twenty']
# Entities: ['Gail', 'Gail', 'One', 'Gail', 'Gail', 'the other day', 'that night']
# Entities: ['William', '7 - year - old', 'Kyle', 'Kyle', 'a couple days', 'Today', 'Kyle', '2 hours', 'Tomorrow']
# Entities: ['Erin']
# Entities: ['Yesterday']
# Entities: ['Ethan', 'first', 'Camelera', 'Clanda']
# Entities: ['Jose', 'Susan', 'Susan', 'Jose', 'Susan', 'Allie', 'a few minutes']
# Entities: ['John', 'Manny', 'last night', 'all night']
# Entities: ['Katie', 'Katie', 'Sue', 'Louis Sears']
# Entities: ['David', '#', 'Jeff', 'a few minutes', 'Brad']
# Entities: ['Smith', 'hours']
# Entities: ['Kate', 'Kate', 'Kate']
# Entities: ['Betty', 'Tom']
# Entities: ['Magdalene', 'two years', 'Caribbean', '2 thousand dollars']
# Entities: ['Sam', 'Jane', 'Jane']
# Entities: ['Mary', 'the holidays', 'Mary', '20 minutes', 'Mary']
# Entities: ['Lonnie', 'daily', 'Kate', 'Kate']
# Entities: ['Randy', 'Frank', 'Randy', 'Frank', 'Randy', 'frank', 'Randy', 'sixth', 'half', 'Two hours later']
# Entities: ['Tony', 'a few days', 'Jacky', 'One day', 'many months', 'Jacky']
# Entities: ['last night', 'Sheila', 'about four days', 'the day', 'Beginning']
# Entities: ['several seconds', 'Jim', 'Billy', 'Jack', 'Joe', 'Jack', 'Joe', 'every minute']
# Entities: ['tubas', 'Dennis']
# Entities: ['Jason', 'Sally', 'a hot day']
# Entities: ['Sarah', 'Sarah', 'all afternoon', '10 minutes', 'Alan', 'One night', 'Ann', 'Jill', 'Jill', 'Alan', 'Jill']
# Entities: ['Tom', 'today', 'Tom', 'today', 'Jane']
# Entities: ['an hour', '13', 'the weekends', 'One', 'Sunday', 'Jake', 'Sunday']
# Entities: ['Half', 'Jane', 'Miami', 'Jane', 'Jane']
# Entities: ['Tina', 'Tina']
# Entities: ['Jenny', 'Ben', 'About twenty minutes later', 'Ben', 'Twenty minutes later']
# Entities: ['Jeff', 'Ashley', 'today', 'Sarah', 'her senior year', 'Win', 'Quentin']
# Entities: ['Mary', 'Mary', 'Kelly', 'night', 'a few minutes', 'Ebroken', 'Kelly']
# Entities: ['Sarah', '6', 'Europe', 'weeks']
# Entities: ['usb', '2011']
# Entities: ['Dan', 'first', 'New York', 'Dan', 'Dan', 'weeks', 'this week']
# Entities: ['Chris', 'all year', 'Chris', 'Nelson']
# Entities: ['Rutherford', 'Physics', 'one', 'Kate', 'noon', 'all summer']
# Entities: ['Josh', 'One day', 'Josh']
# Entities: ['Tim', 'three', 'the second half', 'Tim', 'Tim', 'Tim', 'second', 'Harvard']
# Entities: ['Sarah', 'Sarah', 'two weeks']
# Entities: ['Ike', 'Navy', 'Joe', 'Joe']
# Entities: ['night', 'the end of the night']
# Entities: ['the other afternoon', 'tonight']
# Entities: ['Leslie', 'Leslie', 'Melissa', 'Ed', 'Ed']
# Entities: ['Randy', 'One day', 'Digu', 'a week', 'Hori']
# Entities: ['Lambo Rusty', 'One day', 'a week', 'Joe', 'Mary', 'last weekend', 'the end of the day', 'Mary']
# Entities: ['first', 'Tim']
# Entities: ['Jeff', 'Mike', 'Rob']
# Entities: ['Mark', 'the summer', 'the end of the summer', '10 mph', 'Mike', 'Mike', 'Mike']
# Entities: ['Rafael', 'Doberman', 'Rafael', 'Sam', 'every day', 'that week', 'Sam', 'Sam', 'Sam']
# Entities: ['Emma', 'the day', 'the end of the day', 'half', 'Brandon', '300 dollars']
# Entities: ['Sam', 'Sam', 'Tim', 'Tim', 'a few minutes', 'Tim']
# Entities: ['Caribbean', 'Italian']
# Entities: ['Mark', 'Brittany', 'Mark', 'Mark', 'Chinese', 'Sue', 'a few weeks']
# Entities: ['Sam', '2MPH', 'Sam']
# Entities: ['Ben', 'first day', 'Joe', 'eighteen years old', 'Kayla']
# Entities: ['Tom', 'One', 'Jason', 'Mexicanigoo']
# Entities: ['Josie', 'Years', 'Christmas', 'Christmas', 'Tila', 'the day']
# Entities: ['Two', 'Sam', 'five', 'Sam']
# Entities: ['John', 'John', 'John', 'John', 'Sam', 'Sam']
# Entities: ['Tawny', 'Christmas', 'several minutes']
# Entities: ['Christmas', '2', 'Christmas']
# Entities: ['Lucy', 'Chris', 'only 5 years old', 'One day', "New Year's", "New Year's"]
# Entities: ['Jesus']
# Entities: ['John', 'John', 'John', 'John']
# Entities: ['Yesterday', 'Sam', 'Sam']
# Entities: ['Sam', 'One night', 'months', 'Bob', 'second', 'Every night', 'One night', 'Bob']
# Entities: ['Jerry', 'Monday', 'Jerry', 'Jerry', 'Jerry', 'Jerry', 'every morning', 'Last week']
# Entities: ['Hannah', 'Hannah']
# Entities: ['Larry', 'Larry', 'Larry', 'Larry', 'Joe', 'Joe', 'Joe', 'Joe']
# Entities: ['Joe', 'hundred']
# Entities: ['Braden', 'Braden', 'three weeks', 'Braden', 'one day', 'the hour', 'first']
# Entities: ['Twitch', 'the day']
# Entities: ['Italian', 'Josephine', 'Josephine', 'Bill', 'Bill', 'A few days', 'Bill', 'Bill']
# Entities: ['Thomas', 'Tim', 'three hours']
# Entities: ['One day', 'Jimmy', 'Jimmy', 'Wally', 'Wally', 'three']
# Entities: ['Jill', 'Jill', 'Jill']
# Entities: ['Amy', 'the day', 'Amy', 'that day', 'Jim', 'a good week', 'his first day']
# Entities: ['Verna', 'his first day', 'EMT', 'Bob', 'Bob', 'Bob', 'Bob', 'bee', 'Bob']
# Entities: ['Bobby', 'only nine', 'sixth', 'John', 'John']
# Entities: ['Sam']
# Entities: ['Amy', 'Amy', 'Ben', 'Lynn', 'Amy', 'Amy', 'Anglo', 'Anglo']
# Entities: ['Dave', 'Christmas', 'two months', 'Sue']
# Entities: ['Andy', 'One day', 'Jake']
# Entities: ['John', 'John', 'John', 'one', '2 year old', 'Friday', 'Friday', 'morning', 'all night']
# Entities: ['Philip', 'two']
# Entities: ['Tim', 'Tim', 'Lazarus', 'Lazarus', '20']
# Entities: ['Lisa', 'a few weeks', '6 pounds', 'Billy', 'Billy']
# Entities: ['Carter', 'John', 'John', 'One day', 'John', 'A month later', 'John']
# Entities: ['Mickey', 'Mickey', 'Anna', 'the United States', 'Anna']
# Entities: ['Tina', 'Carlos', 'first', 'Carlos', 'Carlos']
# Entities: ['Kay', 'Kay']
# Entities: ['Tim', 'Tim', 'Tim', 'last year', 'Europe', 'John']
# Entities: ['Tom', 'One day', 'Tom', 'Abby', 'one morning', 'Abby', 'Abby', 'Abby', 'Abby']
# Entities: ['Jane', 'Jane', 'bee', 'Jane', 'Tom', 'Tom', 'Tom']
# Entities: ['many years', 'Sarah', 'Dan', '5 years', 'Sarah', 'Dan', 'Dan', 'One day', 'Dan', 'Dan', 'Sarah', 'Sarah']
# Entities: ['Mike', 'Mike', 'Allie', 'Allie']
# Entities: ['Tom', 'Tom', 'Tom']
# Entities: ['Malcolm', 'sixteen', 'Malcolm', 'Alice', 'summer']
# Entities: ['Marcus', 'Matthew', 'David', 'Elena']
# Entities: ['Jimmy', 'Jimmy', 'Jimmy', 'Abby', 'Abby', 'Abby', 'Abby', 'Abby']
# Entities: []
# Entities: ['One day']
# Entities: ['Marco', 'New York', 'over a thousand', 'the end of the week']
# Entities: ['Sparky', 'the next day', 'five']
# Entities: ['Abigail', 'three years', 'One day', 'Brandon']
# Entities: ['One', 'Sally', 'Sally', 'Sally']
# Entities: ['Mary', 'Christmas', 'Christmas day', 'Jim', 'Jim']
# Entities: ['Jordan', 'Callie', 'Jordan', 'Callie', 'Bob', 'Bob']
# Entities: ['Tom', 'Halloween', 'Will', 'Laura', 'Jake']
# Entities: ['Ahmed', 'Syria', 'Ahmed', 'Ahmed']
# Entities: ['Susie', 'one night', 'Craig']
# Entities: ['Amy', 'Beth', 'Sadie Hawkins', 'Mary']
# Entities: ['Tom', 'Tom']
# Entities: ['Three']
# Entities: ['Jeff', 'two weeks', 'One day', 'a month']
# Entities: ['Harold']
# Entities: ['Fred', 'Sue']
# Entities: ['Mark', 'Tom', 'Tom', 'Tom']
# Entities: ['Joey', 'Joey', 'Tom', 'Tom', 'Tom']
# Entities: ['Mason', 'Mason', 'Allie', 'England', 'Italy', 'Allie']
# Entities: ['Kelly', 'about a minute', 'Kelly', 'James', 'Kelly', 'James']
# Entities: ['Allie', 'Allie', 'Tim', 'Tim']
# Entities: ['Every summer', 'Sarah', 'Sarah', 'Allie', 'iPad', 'Allie']
# Entities: ['Sandra', 'Sam', 'Sam', 'Sam']
# Entities: ['Bobby', 'four', 'a few weeks', 'Bobby', 'one', 'every day', 'weeks']
# Entities: ['Kate', 'one night', 'their relaxing day', 'Kate']
# Entities: ['One day', 'George']
# Entities: ['Tina', 'Costa Rica', 'first', 'Tina', 'first', 'John', 'every day', 'only $ 10 dollars', '10', 'John']
# Entities: ['Friday', 'all week']
# Entities: ['Douglas', 'Tom', 'Tom', 'Tom']
# Entities: ['Lisa', 'One', 'Friday', 'afternoon', 'Tom', 'one', 'Tom']
# Entities: ['one', 'fifteen', 'Charles', 'one morning', 'Charles', 'Charles', 'Charles']
# Entities: ['Charles', 'one', 'Jim', 'Jim']
# Entities: ['today', '15 minutes', 'Lucy']
# Entities: ['Today', 'Tim', 'Tim', 'Tim', 'the day']
# Entities: ['Dan', 'Dan', 'Dan', '5 miles', 'the end of the month', 'Dan', 'more than 30 pounds', 'Dan']
# Entities: ['Martin', 'Jill', 'Jill', 'Jill']
# Entities: ['Muslim', 'Tom']
# Entities: ['Sam', 'Sam', '911', 'Sam', 'James', 'James']
# Entities: ['Sarah']
# Entities: ['Matthew', 'Mario Kart 8', 'Wii U', 'Allie']
# Entities: ['Tim', 'Tim', 'Kate', 'Kate']
# Entities: ['yesterday', 'today', 'Jake', 'One day', 'Jake']
# Entities: ['Angela', 'One', 'Angela', 'Morton', 'One day']
# Entities: ['Jessie', 'Rod', 'two', 'Jessie', 'Rod', 'Sam', 'night', 'Sam']
# Entities: ['3', '2', '1', 'Amy', 'today', 'her first day', 'all week', 'Amy', 'Amy', 'the first day']
# Entities: ['months', 'New Zealand', 'Lucy', 'Lucy']
# Entities: ['Wendy', 'Jim', 'One day', 'Jim', 'Jim', 'Andy']
# Entities: ['night']
# Entities: ['Melanie']
# Entities: ['Lisa', 'Gina']
# Entities: ['Carson', 'Carson', 'one night', 'Kate', 'ten pounds', 'The first weeks', 'Kate', 'a hundred pounds', 'three weeks']
# Entities: ['Joey', 'Texas', 'Tina', 'One day', 'Tina']
# Entities: ['Gary', 'a long day', 'Gary', 'Gary', 'The next day']
# Entities: ['Tom', 'one', 'Anna', 'a nice day', 'Anna', 'Anna']
# Entities: ['Rob', 'Tom', 'Tom', 'Tom']
# Entities: ['Brad', 'Brad', 'Lowell']
# Entities: ['Briana', 'Briana', 'Lima', 'one day', 'Xi']
# Entities: ['Rocky', 'Shelly', 'one morning', 'Shelly']
# Entities: ['Five year', 'Bobby', 'One', 'Bobby', 'Jason', 'Lucy', 'Lucy']
# Entities: ['Tara', 'summer', 'all summer', 'summer', 'Jane', 'iPad', 'Jane']
# Entities: ['Anna', '4th', 'Anna', 'the last minute', 'Anna', 'Anna']
# Entities: ['Gina', 'summer afternoon', 'a few miles']
# Entities: ['four', 'Villanova', 'Oklahoma', 'Saturday night', 'Sunday', 'North Carolina', 'Notre Dame', '10th', 'Syracuse', '1', 'Virginia']
# Entities: ['yesterday']
# Entities: ['Jerry', 'the day', 'summer', 'Madras', 'Three months', 'Cry']
# Entities: ['Sasha']
# Entities: ['Joe', 'Joe', 'the end of the week', 'Joe', '20 pounds']
# Entities: ['Jenny', 'weekly', 'Jenny', 'Jenny', 'Ben', 'Ben']
# Entities: ['Bea', 'Mike', 'Mike', 'Bea', 'Tom', 'Tom', 'Tom', 'Tom', 'Tom']
# Entities: ['Tony', 'hours', 'One day', 'Deit', 'One day', 'Embb', 'Embb']
# Entities: ['John', 'Youa']
# Entities: ['this day', '2011', '17 year old', 'Maria', 'second', 'Maria', 'Dan', 'Dan', 'Dan', 'Dan']
# Entities: ['Florence', 'Fifth', 'Fifth']
# Entities: ['Mia', 'Mia', 'Sam', 'Sam']
# Entities: ['Jason', 'Bruno']
# Entities: ['Jelly', 'Anna', 'her first week', 'a few weeks', 'Anna']
# Entities: ['Jason', 'first day']
# Entities: ['Tim', 'Tim', 'Tim']
# Entities: ['Bradley', 'one', 'Bradley', 'Lucy', 'One', 'the summer']
# Entities: ['Tim', 'Tim', 'Tim', 'Brandon', 'Lisa', 'One year', 'dinnerQ', 'Lisa', 'Sally']
# Entities: ['Tom', 'night', 'Tom', 'Mary', 'Christmas', 'only one', 'Mary', 'one', 'Mary']
# Entities: ['Kevin', 'one day', 'Kevin', 'Kevin', 'Tom', 'one day', 'Tom']
# Entities: ['Hunter']
# Entities: ['Zeke', '45']
# Entities: ['Last Saturday', 'late night', 'Burnt', 'midnight', 'Amy', 'Christmas', 'Amy', 'all day', 'an hour', 'Amy', 'the afternoon']
# Entities: ['winter']
# Entities: ['DC', '2008', 'Mormon', 'Mormon', 'Today', 'Jeff', '7th', 'Sara Leonee', 'many years ago', 'Theresa']
# Entities: ['Sarah', 'one', 'Sarah', 'Diane', 'second']
# Entities: ['Matt', 'a couple months', 'Matt', 'two years', 'Tina', 'Tina']
# Entities: ['Bill', 'Last week', '5', 'Josh', 'Josh']
# Entities: ['John', 'John', 'one', 'John', 'Kate', 'Kate']
# Entities: ['five', 'Two', 'One', 'a week']
# Entities: ['2012']
# Entities: ['Terry', 'Terry', 'Terry', 'next year', 'first']
# Entities: ['Carl', 'Carl', 'the next few days', 'ho', 'One evening', 'Ya']
# Entities: ['Carl', 'Susie']
# Entities: ['Carl', 'Fred', 'Fred', 'Fred', 'Derek', 'yesterday']
# Entities: ['Sam', 'years', 'Sam', 'Amy', '37 dollars', 'Amy', 'Amy']
# Entities: ['Marsha', 'John', 'John', 'John']
# Entities: ['a year', 'two years', 'Last night', 'next night']
# Entities: ['Erica', 'Ben', 'Ben']
# Entities: ['a few days', 'Months', 'Kim', 'Kim', 'Kim', 'Kim']
# Entities: ['Edgar']
# Entities: ['Mike', "one o'clock", 'five', 'Mike', 'Mike', 'two']
# Entities: ['Ronnie', 'Kevin', 'Jane', 'Jane', 'Steve', 'three', 'UCLA']
# Entities: ['early in the morning', 'Jones', 'last week']
# Entities: ['Tommy', 'today', 'Tommy', 'Tommy', 'Jane', 'Jane', 'Jane']
# Entities: ['Moutai', 'years ago', 'Red Sorghum', 'Moutai', 'One', 'Anna']
# Entities: ['Dan', 'Jim', 'One day', 'One', 'Jim', 'Jim']
# Entities: ['Kim', 'Kim', 'one']
# Entities: ['Tom']
# Entities: ['overnight', 'Sam', 'twenty minutes']
# Entities: ['John', 'John', 'one']
# Entities: ['Abby', 'Abby', 'Sue', 'Italy', 'many weeks']
# Entities: ['Tom', 'Tom']
# Entities: ['Kia', 'March', 'half', 'Congressed']
# Entities: ['Bob', '6 years ago', 'Bob', 'Jake', 'Jake']
# Entities: ['Kasey', 'Peggy', '95 years old', 'a whole week', 'Peggy']
# Entities: ['Kia', '16', 'Kai', 'Amy', 'Mark']
# Entities: ['Sam', 'Sam', 'Jack', 'Sally', 'Disney World', 'Disney']
# Entities: ['Chris', 'Doug', 'John', 'John', 'about an hour', 'next day', 'John']
# Entities: ['Sally', 'Sally', 'One day', 'Jason', 'Jason']
# Entities: ['Herman', 'first', 'second', 'Tom', 'Tom']
# Entities: ['Amy']
# Entities: ['Susie', '1 mile', 'every day', 'the day', 'One year', 'The next year']
# Entities: ['Harry', 'Alice']
# Entities: ['Beverly', 'Beverly', 'One', 'Last week']
# Entities: ['Ray', 'Halloween day']
# Entities: ['Bob', 'a few hours', 'Carlos', 'New York', 'New York', 'Carlos', 'every single day', 'New York', 'Spanish']
# Entities: ['Brian', 'Las Vegas', 'An hour later', 'Las Vegas', 'hours']
# Entities: ['days', 'England']
# Entities: ['Mary', 'Tom', 'yesterday', 'Mary', 'Mary', 'Mary', 'Mary', 'Tom']
# Entities: ['Cindy', 'Jack', 'One day', 'Jack', 'Jack']
# Entities: ['Chris', 'Anna', 'the summer', 'weeks', 'Anna']
# Entities: ['Jenny', 'last night', 'thirty minutes', 'five minutes', 'Tom', 'Tom', 'Tom']
# Entities: ['Barbara', 'Barbara', 'One day', 'three', 'Rick']
# Entities: ['Bob', 'Batman', 'Bob', 'Tina', 'first', 'Tina']
# Entities: ['Jane', 'Fredor', 'Fredda']
# Entities: ['Jasmine', 'Tim']
# Entities: ['Joe', 'Late at night', 'Robert', 'Robert', 'The day', 'Carl']
# Entities: ['Nick', 'Nick', 'Basil', 'fourth', 'many hours', 'Louie']
# Entities: ['Tom', 'Tom', 'Sam', 'Sam', 'The next day', 'Sam']
# Entities: ['Shelly', 'Ricky']
# Entities: ['Smith', 'Jimmy', 'One', 'Jimmy', 'Dan', 'Dan', 'Dan', 'Dan']
# Entities: ['Sally', 'all night', 'Sue', 'Sue']
# Entities: ['Tim', 'only 3 minutes']
# Entities: ['Jim', 'Branch', 'only three', 'toy.9']
# Entities: ['Tom', 'Tom', 'Chaaden', 'Chaden']
# Entities: ['Peter', 'Peter', 'John', 'daily']
# Entities: ['Tom', 'Tom']
# Entities: ['Jane', 'polish', 'Bob', 'Bob', 'Ann', 'afternoon', 'The evening']
# Entities: ['Rob', 'Kerala', 'the next day']
# Entities: ['Susan', 'a very busy morning']
# Entities: ['Matt', 'Tom', 'Tom']
# Entities: ['Rachel', '1987', 'two days']
# Entities: ['Tom', 'Liz', '5 months', 'Tom', 'Liz', 'one night']
# Entities: ['Kyle', 'Kyle', 'Sam', 'from school one day', 'Sam', 'Sam']
# Entities: ['Jane', 'last week', 'Jane', 'Tardi', 'night']
# Entities: ['Korean', 'Asian']
# Entities: ['Joe', 'Joe', 'Tina', 'weeks', 'Tina']
# Entities: ['Last week', 'about two hours', 'a few hours', 'two hours']
# Entities: ['Betty', 'Tim', 'Tim', 'half', 'Tim', '911']
# Entities: ['One day']
# Entities: ['Kim', 'One day', 'James', 'James']
# Entities: ['Steak N Shake', 'Cathy', 'Kim', 'Kim', 'Kim', 'Kim', 'Kim', 'five']
# Entities: ['Chinese', 'yesterday', 'John', 'two', 'John', 'first', 'Spanish', 'John']
# Entities: ['Alice']
# Entities: ['13', 'first']
# Entities: ['a week']
# Entities: ['Susie']
# Entities: ['Disneyworld', '1995', '9', 'Dumbo', 'the Magic Kingdom', 'One night', 'Ben']
# Entities: ['Bobby', 'Bobby', 'Marrah']
# Entities: ['Bob', 'Bob', 'Brooks', 'Julie', 'the day', 'Julie', 'Julie']
# Entities: ['Rex', 'Rex', 'Tom', 'Tom', 'Tom', '10', 'Tom', 'Tom', '2nd']
# Entities: ['Dan', 'first', 'Tom', 'weeks']
# Entities: ['Only two', 'Laura', 'first', 'one day', 'Fred']
# Entities: ['one day', 'Walter', 'Gail']
# Entities: ['Tim', 'Tim', 'John', 'John', 'today', 'John']
# Entities: ['Justin', 'one day', 'Carson', 'the first day', '98']
# Entities: ['Olympians', 'Jesus', '44', 'UCLA']
# Entities: ['about an hour', 'John', 'John', 'John', 'John']
# Entities: ['Tiburon', 'the San Francisco Bay', 'Sally']
# Entities: ['one night', 'Mark']
# Entities: ['Tim', 'One day', 'Tim', 'every morning']
# Entities: ['1975', 'Plymouth', 'Plimoth Plantation', 'John', 'John', 'John', 'John']
# Entities: ['Jen', 'third', 'late this week']
# Entities: ['Chelsea', 'Tom', 'Tom', 'a half mile', 'Tom', 'Tom']
# Entities: ["Saint Patrick's", 'today']
# Entities: ['Riley', 'Sam', 'Sam', 'the day']
# Entities: ['Rob', 'Rob', 'Hannah']
# Entities: ['One day', 'Anna']
# Entities: ['Wanda', 'Tim', 'all day', 'One day', 'Tim', 'Tim']
# Entities: ['Alex', 'Alex', 'Dad', 'Alex', 'Pepto Bismol', 'Tom', 'One', 'Tom', 'Tom']
# Entities: ['Tom', 'Tom', 'summer', 'summer']
# Entities: ['Mary', 'Mary', 'Mary']
# Entities: ['Kia', 'sixteen', 'Kia', 'Kia', 'three', 'Minnesota', 'three', 'today']
# Entities: ['John', 'the last minute', 'two seconds', 'John', 'John']
# Entities: ['Kate', 'Kate', 'Lucy', 'Lucy', 'One day', 'Lucy']
# Entities: ['one', 'John', 'John', '10 pounds', 'un']
# Entities: ['Cindy', 'twenty', 'first', 'Jake']
# Entities: ['Paul', 'weekly', 'first', 'Sam', 'Sam', 'Sam']
# Entities: ['YouTube', '10 minutes', 'Jim', 'Jim', 'Jim']
# Entities: ['Tim', 'summer', 'Bob', 'Bob']
# Entities: ['Dan', 'Dan', 'Dan', 'Dan', 'Coleman']
# Entities: ['Christmas day', 'Christmas', 'Mary', 'Mary', 'Mary', 'first']
# Entities: ['Jasper', 'California', 'Every day', 'Homelim', '6th', 'Tommy', 'years']
# Entities: ['Max', 'Max', 'Jeff', 'a few minutes Jeff', 'Jeff']
# Entities: ['Sam', 'Sam']
# Entities: ['Jane', 'Jane', 'Jane', 'Mary', 'Mary']
# Entities: ['A few seconds later', 'Mike', 'annual']
# Entities: ['Tom', 'Tom', 'Stocky', 'Frisbee', 'Frisbee', 'Frisbee', 'frisbee']
# Entities: ['George', 'Christmas', 'Christmas', 'Sunday', 'Monday', 'Cathy', 'Cathy', 'Cathy']
# Entities: ['Mississippi', 'the other day']
# Entities: ['One day', 'Fred']
# Entities: ['Tom', 'hours every day', 'Tom', 'first', 'Rosemary']
# Entities: ['Lynn', 'February 22', '222', '222', 'Lynn', 'Bill', 'One', 'Bill', 'One']
# Entities: ['Ranger', 'Ranger']
# Entities: ['half', 'one', '22 years old', 'Craigslist', 'Craigslist']
# Entities: ['John', 'Korean', 'Octopus', 'Korean', 'Octopus', 'Tina', 'the day', 'Tina', 'three', 'Tina', '5']
# Entities: ['April', 'Jake', 'Jake']
# Entities: ['Amy', 'morning', '3 hours', 'first', 'Melissa']
# Entities: ['Arnold', 'one day', 'Mary', 'Christmas', 'Mary', 'a great day of Christmas']
# Entities: ['Allie', 'Fred']
# Entities: ['Oliver']
# Entities: ['Ned', 'Call of Duty', 'Doritos', 'Amy', 'Saturday', 'five', 'Amy', 'the last minute', 'Amy']
# Entities: ['Lori', 'One day', 'Lori', 'Lori', 'Bill', 'Bill', 'One day', 'Bill', 'Bill', 'Bill']
# Entities: ['today', 'Harvard Square', 'a few minutes ago', 'One day', 'two', 'a whole day', 'two']
# Entities: ['Xbox', 'all night']
# Entities: ['Australia', 'koalas', 'Tom', 'Tom']
# Entities: ['6 AM', 'Gina', 'Minnesota', 'Sam', 'one day', 'Sam']
# Entities: ['Evan', 'Alex', 'field day', 'Evan', 'Alex', 'Elias', 'One day', 'Eric', 'Kurt', 'Coal']
# Entities: ['Tina', 'Tina', 'late at night', 'One night', 'Tina', 'Tina']
# Entities: ['Danny', 'Danny', 'Danny', 'Amy', 'Italian', 'Amy', 'Europe', 'Amy', 'Amy']
# Entities: ['Tom', 'Tom', 'Matt', 'three']
# Entities: ['bee']
# Entities: ['an early age', 'one day', 'Tom', 'Tom', 'Tom']
# Entities: ['Kelly']
# Entities: ['Walter', 'One day', 'first', 'third', 'Malcolm']
# Entities: ['Richard', 'One', 'Richard', 'six months', 'Richard', 'every day', 'Nicholas', '50 years old', 'today', 'fourth', 'Nick', 'Nick', 'a great day']
# Entities: ['Ramon', 'Ramon', 'early morning', 'Ramon', 'night', 'Walter', 'three weeks', "four months's", 'Walter', '1', '000']
# Entities: ['Mike', 'Mike', 'Gradually Mike', 'John', 'One day', 'John']
# Entities: ['two years', 'One day']
# Entities: ['John', 'two', 'Every year', 'Halloween', 'this year', 'prior years', 'Tom', 'Tom']
# Entities: ['Bill', 'Bill', 'Bill', 'Bill', 'YouTube', 'Bob', '8 hours', 'Bob', '8 hours', 'Bob']
# Entities: ['Hallie', 'Mike', 'Mike']
# Entities: ['Beth', 'Joe', 'several hours', 'Beth', 'first', 'Amy']
# Entities: ['yesterday', 'Christmas']
# Entities: ['Allie']
# Entities: ['Michael', 'Kim', 'every morning', 'Kim', 'One day', 'Kim']
# Entities: ['the other day', 'Tim', 'a few hundred pounds']
# Entities: ['Cross Country', 'up to 10 miles', 'One day', 'Emily']
# Entities: ['Tim', 'Tim', 'Tim']
# Entities: ['Jillian', 'One', 'Jillian', 'Jillian', 'Jillian', 'Jack', 'Jack']
# Entities: ['Molly', 'Susan', 'the beginning of summer', 'The first day', 'two', 'Kim', 'Kim', 'Kim']
# Entities: ['night', 'late at night', 'Abby', 'Jake', 'one']
# Entities: ['Earl', 'four percent', 'Earl', 'two percent', 'Earl', 'seven years old']
# Entities: ['Karen', 'summer', 'twenty pounds', 'the First 3rd of July', '4 year old']
# Entities: ['Haley', 'Halloween']
# Entities: ['Olympics', 'four years', 'five', 'every day', 'a month', 'the day']
# Entities: ['Jack', 'eighth', 'Jason', 'One day', 'Jason']
# Entities: ['Yolanda']
# Entities: ['Greg', 'Greg', 'Jason']
# Entities: ['Randy', 'One day', 'Simpsons', 'Randy', 'that day', 'summer afternoon']
# Entities: ['Jerry', 'One day', 'Later that day', 'Jerry', 'Mindy']
# Entities: ['Javier', 'today', 'Javier', 'Amy', 'the next morning']
# Entities: ['first', 'Christmas']
# Entities: ['Dee', 'Dee', 'Sam', 'Sam', 'one', 'Sam']
# Entities: ['Today', 'Tom', 'Tom']
# Entities: ['Tim', 'Tim']
# Entities: ['Josh', 'Josh', 'Josh', 'josh', 'Hawk', 'John', 'tomorrow', 'John', 'John', 'John', 'John']
# Entities: ['Lawrence', 'Anna', 'Anna']
# Entities: ['first', 'One day', 'Jake', 'Jake']
# Entities: ['Tony', 'Nia', 'Nia', 'One', 'Tony', 'Nia', 'Tony', 'Tim', 'several months', 'Tim', 'Tim', 'a mile', 'a month', 'Tim', 'Tim', 'ten mile mile']
# Entities: ['Adam', 'Alice', 'Joyce']
# Entities: ['Sebastian', 'Sebastian', 'every day', 'months']
# Entities: ['a few hundred dollars', 'Finally Sue']
# Entities: ['John', 'John', 'John', 'Jake', 'a few minutes']
# Entities: ['Chris', 'James', 'James', 'Chris', 'James', 'Sue', 'the next day']
# Entities: ['One day', 'James', 'James', 'James']
# Entities: ['Rome', 'Jack', 'Jack', 'Harper', 'Jack', 'Checkrs', 'Jack', 'Stockrs', 'Steprs on Facebook', 'Checkrs']
# Entities: ['Clint', 'Frisbee', 'Clint', 'Frisbee', 'Frisbee', 'two year old', 'New York']
# Entities: ['Hannah', 'Hannah', 'Hannah', 'the weekend day']
# Entities: ['Bill', 'Bill', 'Bill', 'Bill', 'James', 'James', 'every night', 'every night', 'the day', 'James']
# Entities: ['One day', 'Ben', 'Ben', 'Ben', 'Ben']
# Entities: ['Cora', 'Cora', 'One day', 'Cora', 'Smiths', 'Smiths', 'Smiths']
# Entities: ['one day']
# Entities: ['Matt', 'the next five weeks']
# Entities: ['Scott', 'Scott', 'today', 'a surprisey day']
# Entities: ['morning', 'one week ago', 'two days']
# Entities: ['Today', 'Halloween', 'James', 'James', 'James']
# Entities: ['Tim', 'Jake']
# Entities: ['Alice', 'Youtube', 'thousands', 'a month', 'Sam', 'Sam', 'two months']
# Entities: ['Colby', 'Colby', 'Colby', 'Tom', 'Tom']
# Entities: ['Jill', 'a few days', 'another few weeks', 'Jill', '5 minutes']
# Entities: ['Bryce', 'Bryce', 'Bryce', 'Bryce', 'Sam', 'Sam', 'Sam']
# Entities: ['Mary', 'Mary', 'Tom', 'every night', 'Tom', 'Tom']
# Entities: ['Jake']
# Entities: ['13', 'Oregon', 'Duke']
# Entities: ['Stephanie', 'first', 'years', 'One day', 'Joe', 'Joe', 'Joe', 'Joe']
# Entities: ['Abby', 'many months', 'many months', 'Abby']
# Entities: ['John', 'Uncle', '4 Years']
# Entities: ['Julie', 'Julie', 'Ben', 'first', 'hours', 'hours', 'Ben', 'Ben']
# Entities: ['Kevin', 'One day', 'Anna', 'Anna']
# Entities: ['an hour']
# Entities: ['all week', 'Nelly', 'Allie', 'Allie']
# Entities: ['Kendra', 'first', 'Jason', 'Sue', 'Jason', 'Sue', 'Sue', 'Mark', 'Mark']
# Entities: ['Jenny', 'today', 'Jenny', 'Jenny', 'Kelly', 'Kelly']
# Entities: ['almost a week', 'Jim', 'Jim', 'Jim', 'Jim']
# Entities: ['the next day', 'two', 'Kate']
# Entities: ['One day', '2 week', 'Lunch', 'iPod', 'five', 'Last week', '100']
# Entities: ['Cathy', 'Cathy', 'one day', 'years', 'Jake']
# Entities: ['Kyle', 'December day', 'Allie']
# Entities: ['Jack', 'This year', 'first', 'B. Marvo', 'five']
# Entities: ['Jim', 'Pittsburgh', 'the week', 'Rosemary', 'four', 'two']
# Entities: ['Ron', 'Tom', 'Tom', 'Tom', 'Toni']
# Entities: ['Teddy', 'John', 'John', 'John', 'six months']
# Entities: ['every day', 'One', 'Anna', 'Anna']
# Entities: ['Juan', 'that morning']
# Entities: ['Bob', 'Charles', 'Principal']
# Entities: ['Bob', 'Bob', 'the next day', 'Erica']
# Entities: ['Last night', 'Sam', 'Sam', 'Sam']
# Entities: ['Ella', 'Ella', 'Josephine']
# Entities: ['Tom', 'overnight', 'the next day', 'Tom', 'James']
# Entities: ['Tom', 'Tom', 'Ben', 'night', 'the last minute', 'Ben']
# Entities: ['one', 'Lisa Frank', 'Dave', 'Gina', 'it.al']
# Entities: ['hours', 'Tom', 'Tom', 'Tom', 'Tom']
# Entities: ['Donald', 'first', 'One', 'Byrd']
# Entities: ['One day', 'Mary', 'Tom', 'Tom']
# Entities: ['Christina', 'Christina', 'Josh', '7th']
# Entities: ['Julie', 'Tim', 'night', 'Tim']
# Entities: ['Rock Tobago', 'One weekend', 'Scott', 'Ryan']
# Entities: ['Sam', 'Jim', 'Jim', 'Tina', 'Tina']
# Entities: ['Anne', 'morning', 'Anne', 'Tim', 'the end of the week']
# Entities: ['Tim', 'Joe', 'two hours', 'next year']
# Entities: ['Annie', 'Greg', 'the 4th of July', 'Joe', 'Joe']
# Entities: ['Renee', 'last night', 'a few days']
# Entities: ['Tom', 'Jewish', 'Tom', 'a few days ago', 'Target Sears']
# Entities: ['Kate', 'Kate', 'Chico', 'Rick']
# Entities: ['Tom', 'Tom', 'Sam', 'Sam', 'Sam', 'Sam', 'Sam', 'Sam']
# Entities: ['Mike', 'weeks']
# Entities: ['four', 'two', 'Jane', 'Jane']
# Entities: ['recent years', 'One', 'Waterpack', '7']
# Entities: ['John', 'One', 'Mary', 'John']
# Entities: ['one', 'Mike', 'Mike']
# Entities: ['Xena', 'night', 'Xena', 'two pounds', 'James', 'Anna', 'Anna', 'James']
# Entities: ['Miranda', 'a hundred dollars']
# Entities: ['Jackson', 'two', 'Anne - Marie', 'Massachusetts']
# Entities: ['the morning', 'Billy']
# Entities: ['Janie', 'that day', 'Allie']
# Entities: ['12 hours', 'Law', 'first']
# Entities: ['Gary', 'Gary', 'years ago', 'Gary', 'Tim', 'eighth']
# Entities: ['Grandpa', 'today', 'noon', 'Mary', 'all day', 'the worst day']
# Entities: ['one morning']
# Entities: ['Oliver', 'Kim', 'Kim']
# Entities: ['Liam', 'one', 'Liam', 'Anna', 'Anna', 'Anna']
# Entities: ['Lisa', 'Philip', 'Dirk']
# Entities: ['Lil Zeer', 'Young Bee', 'Young bee', 'a week', 'Anna', 'Anna']
# Entities: ['Justin', 'Jerry', 'Jerry', 'Jerry']
# Entities: ['Steve', 'Lana', 'Steve', 'Lana', 'Lana', 'Steve', 'Tina', 'Tina']
# Entities: ['Amy', 'her first day', 'Amy', 'Amy']
# Entities: ['Nina', 'Jake', 'one']
# Entities: ['the season', 'every day', 'Fred', 'One', 'Fred', 'Fred']
# Entities: ['Eddie', 'Eddie', 'Eddie', 'Anna', 'the summer', 'the summer', 'Anna', 'Anna']
# Entities: ['Lola']
# Entities: ['George', 'George', 'Charles']
# Entities: ['Tom', 'night', '2013', 'the day', '2nd']
# Entities: ['Tom', 'Tom']
# Entities: ['California Provincial']
# Entities: []
# Entities: ['Bill', 'Bill', 'Bill', 'first', 'Bill']
# Entities: ['Randy', 'Amy', 'Sam', 'Sam']
# Entities: ['Tom', 'Tom', 'Tim', 'Tim', 'Tim']
# ...
# Entities: ['Jamie', 'ten', 'Jamie', 'five', 'the first half', 'the second half', 'Jamie']
# Entities: ['Craig', 'Christmas']
# Entities: ['Megan', 'One afternoon Fred']
# Entities: ['Anna', 'one morning', 'Anna', 'all day']
# Entities: ['Later that day', 'Kim']
# Entities: ['Sam', 'One day', 'Sam', 'herry fish']
# Entities: ['Bethany', 'Bethany', 'One day']
# Entities: ['Daisy', 'Daisy', 'One', 'First']
# Entities: ['Walter', 'Bill', 'One day', 'Bill']
# Entities: ['Bee', 'Roy', 'Adam', 'Sue', 'Sue', 'Sue']
# Entities: ['Beth', 'A week later', '10', '10']
# Entities: ['Jim', 'Tim', 'Tim', 'Tim']
# Entities: ['Rachel', 'Becky', 'Becky', 'Rachel', 'Marsha', '20 years old', '5 years', 'a month']
# Entities: ['Paul', 'Paul', 'Anna', 'Anna']
# Entities: ['Charles', 'Mark', 'Rob']
# Entities: ['Liz', 'Liz', 'Kelly', 'Liz', 'Kate', 'her first day', 'Kate', 'that day']
# Entities: ['Abe', 'Kelly', 'Kelly', 'Kelly']
# Entities: ['Jen', 'Jen', 'today', 'Sue', 'Sue']
# Entities: ['Susie', 'all week', 'That night', 'Susie', 'first']
# Entities: ['15 thousand miles', 'months', 'Tom']
# Entities: ['ten days', 'Tom', 'One day']
# Entities: ['Anna', 'Christmas', 'Christmas']
# Entities: ['Margaret', 'Margaret', 'Kim', 'two month', 'Kim', 'Kim']
# Entities: ['Final Fantasy 7', 'Cynthia']
# Entities: ['Rob', 'Marines', 'ROTC', '18', 'Rob', 'Tim', 'Tim', 'Tim', 'all day', 'Tim']
# Entities: ['the morning', 'Katie', 'first', 'Katie', 'Tina', 'next week']
# Entities: ['Joey', 'today', 'Kelly', 'Kelly']
# Entities: ['Diane', 'all week']
# Entities: ['today', 'every day']
# Entities: ['Tom', 'daily', 'Tom', 'half a year', 'Halloween']
# Entities: ['next weekend', 'John', 'John', 'Anna', 'Anna']
# Entities: ['Kate']
# Entities: ['Keenan', 'Keenan', 'Keenan', 'Jill', 'Jill', 'every day', 'One day', 'Jill', 'hours', 'Jill']
# Entities: ['Janet', 'first', 'Mary', 'every g minute']
# Entities: ['Joe', 'Joe', 'Joe', 'Joe']
# Entities: ['Tom', 'Tom']
# Entities: ['Jerome', 'Jerome', 'Ela', 'one morning', 'the birth day']
# Entities: ['Scott', 'five', 'One day', 'Scott', 'Joe', 'Joe']
# Entities: ['an hour', 'Allie', 'Allie']
# Entities: ['this afternoon', 'Baltimore', 'Lucy', 'Lucy']
# Entities: ['Tom', 'Congress', 'Alex', 'Harry', 'Harry', 'Harry']
# Entities: ['Lucy', 'Lucy', 'Bill', 'one night', 'Bill', 'Bill']
# Entities: ['George', 'George', 'Tom']
# Entities: ['Monday', 'Sunday', 'five', 'the next day', 'Morgan', 'Shelly']
# Entities: ['Gavin', 'Emily', 'one', 'Jason', 'Jason', 'Jason']
# Entities: ['Christmas', 'this Christmas', 'Rrita', 'One day']
# Entities: ['Rebecca', 'Rebecca']
# Entities: ['a very hot day', 'Brandon']
# Entities: ['Jason', 'Jason', 'Jason']
# Entities: ['Kade', 'Kade', 'Mary', 'one', 'Mary']
# Entities: ['John', 'first', 'Jill', 'first', 'seven', 'two', 'Jill', 'the weekend']
# Entities: ['months', 'One day', 'first']
# Entities: ['summer', 'Branson', 'MO', 'one summer', '4 years', 'Branson', 'James', 'James', 'first', 'James']
# Entities: ['Patrick', 'the first day', 'Gary', 'Gary', 'Gary', 'Gary', 'Gary']
# Entities: ['Karen', 'four', 'five', 'Tasha', 'Karen', 'the first five years', 'Tasha', 'three weeks', 'fifth']
# Entities: ['May']
# Entities: ['Arnold', 'One day', 'first', 'Jack', 'Tokyo', 'Christmas morning', 'Jack', 'Boston', 'another week', 'Buffalo', 'Jack']
# Entities: ['Yesterday', 'Kelly']
# Entities: ['Tim', 'Tim', 'Tim', 'Tim', 'every other evening', 'Bill', 'Bill', 'Bill', 'One day', 'Bill apologized']
# Entities: ['Tom', 'One', 'Billy']
# Entities: ['yesterday', 'Mary', 'ten years old', 'Mary', 'one day', 'Mary', 'Mary', 'Mary', 'Mary']
# Entities: ['Tia']
# Entities: ['Sarah', 'two', 'Brandon']
# Entities: ['Bernardo', 'Toro', '20', 'Toro', '20']
# Entities: ['Howard', 'Howard', 'hours', 'four']
# Entities: ['Gary', 'Gary', 'a tour one day', 'thousands', 'Smith', 'every summer', 'This summer', 'Las Vegas', 'them half four hours', 'Las Vegas']
# Entities: ['William', 'William', 'William', 'Bob', '100', '000', 'Bob']
# Entities: ['Brian', 'Brian', 'Brian', 'Brian', 'Last week', 'today']
# Entities: ['Kevin']
# Entities: ['first', 'Paw Patrol', 'Tim', 'two', 'One night', 'that night']
# Entities: ['Harry', 'The next day', 'Harry', 'Harry', 'Kayy', '5th', 'Kayla', 'Kayy', 'the best day']
# Entities: ['all day', 'Jake', 'a month']
# Entities: ['Tiffany', 'her very first Christmas', '4 feet', 'Walter', 'one day', 'Jerry']
# Entities: ['Joe', 'Joe', 'William', 'William', 'Tang']
# Entities: ['Joe', 'Joe', 'Joe']
# Entities: ['A few minutes later', 'Sarah', 'Sarah', 'Sarah', 'first']
# Entities: ['Paris', 'Jill', 'Jill', 'a week']
# Entities: ['Callie', 'Callie', 'two', 'Callie', 'Sally', 'Sally']
# Entities: ['Jenny', 'Tim', 'an hour', 'Tim']
# Entities: ['Bob', 'The last minute', 'Ben', 'half', 'the day']
# Entities: ['Sally', 'Italian', 'Sally', 'Sally', '100', 'an hour']
# Entities: ['Tyler', 'Tyler', 'Tyler', 'Mary', 'third', 'last Year', 'two', 'Mary', 'next year']
# Entities: ['three months', 'Roy', 'Roy']
# Entities: ['Marsha', 'One day', 'Kay', 'Kay']
# Entities: ['Sally', 'Sally']
# Entities: ['Alan', 'Alan', 'one']
# Entities: ['Trisha']
# Entities: ['Jane', 'Jane', 'bush', 'third', 'Halloween', 'One']
# Entities: ['Billy']
# Entities: ['Last Monday', 'four hours', 'Charlie won Monopoly', 'Sue', 'Trivial Pursuit', 'the end of the night', 'Jasmine', 'Raiders', 'one night', 'Ayo, Ake']
# Entities: ['Ethan', 'Jill', 'Ethan', 'Jill', 'Mary']
# Entities: ['Jean', 'Jill', 'Jill']
# Entities: ['Paul', 'Paul', 'Sam', 'Sam', 'Sam']
# Entities: ['Every couple of years', 'Dean', 'the first day', 'Dean', 'one day', 'every day', 'Sue', 'Sue']
# Entities: ['Susan', 'Susan', 'Tom', 'Tom', 'Tom']
# Entities: ['first', 'late March', 'Gary', 'Gary', 'Gary', 'Gary']
# Entities: ['Frank', 'Umberto', 'Boston', 'Newton', 'this week', 'Joe', 'Joe', 'the next week', 'Joe']
# Entities: ['Marvin', 'first', 'Sarah', 'Marvin', 'Jake']
# Entities: ['Carl', 'twenty eight', 'Carl', 'Tim', 'Tim', 'two', 'Tim', 'Tim']
# Entities: ['Brad', 'Brad', 'Brad', 'Tim', 'one night', 'midnight', 'Tim', 'several years']
# Entities: ['Ted', 'all night', 'The day', 'Ted', 'Hannah', 'One']
# Entities: ['Frank', 'Louis', 'Frank', 'Frank', 'Louis', 'Anna', 'One day', 'Anna']
# Entities: ['Ted', 'the Middle East', 'the day', 'Ted', 'Charles', 'the night', 'Charles', 'the night']
# Entities: ['Tina', 'Tina']
# Entities: ['Lucy', 'Tim', 'one afternoon']
# Entities: ['Ruth', 'Ruth']
# Entities: ['one every Tuesday', 'Thursday', 'morning', 'Anna']
# Entities: ['Grace', 'Grace', 'Tina', 'Tina']
# Entities: ['Tim', 'fifteen minutes', 'Kayla', 'Christmas', 'every week', 'a month', 'the next month', 'the end of the month']
# Entities: ['Lawrence', 'Lawrence', 'Australia', 'Australia', '12 hour', 'two weeks', 'Jesus', 'two', 'two weeks', '45']
# Entities: ['Jack', 'today', 'Jack', 'Jack', 'Fluffy', 'Jack', 'all day', 'Kyle', 'that afternoon', 'Kyle']
# Entities: ['Max', 'Grandpa', 'first', 'years', 'Max', 'Max', 'Charles']
# Entities: ['Mark', 'about 10 minutes', 'Ethan', 'Colin', 'Ethan', 'Ethan']
# Entities: ['Hollywood Studios', 'the day', 'first', 'the morning', 'the Tower of Terror', 'night', 'Tim', 'Tim']
# Entities: ['Julia', 'Julie', 'One day']
# Entities: ['One day', 'Allie', 'Allie']
# Entities: ['about two miles', 'a few minutes later', 'Alice', 'Butta']
# Entities: ['a few minutes', 'Kia', 'one', 'weeks', 'half', 'Kia']
# Entities: ['today', 'a month', 'a month', 'Charles', 'first day', 'Charles', 'James', 'James', 'Charles', 'Charles', 'Charles', 'Charles']
# Entities: ['Tim', 'Tim', 'weeks']
# Entities: ['Sam', 'Hairummy Fry', 'Sam', 'all day', 'Sam', 'One day', 'Sam', 'Sam']
# Entities: ['the day', 'One', 'Kelly', 'Kelly']
# Entities: ['Jim', 'first', 'Lisa', 'this morning', 'about an hour', 'all day', 'Nancy']
# Entities: ['Candace', 'Texas', 'Fred', 'first']
# Entities: ['John', 'Barr', 'Montana', 'one', 'Barr']
# Entities: ['One day', 'Blight', 'Bi', 'Newport', 'Bi']
# Entities: ['Bill', 'Bill', 'Bill', 'Bill', 'John', 'John', 'five']
# Entities: ['Briana', 'that morning', 'Basil']
# Entities: ['Clark', '7th']
# Entities: ['Ethan', 'Mike', 'first', 'tonight', 'Mike']
# Entities: ['one evening', 'Tara', 'Tim', 'night', 'Tim']
# Entities: ['Sam', 'One day']
# Entities: ['Sam', 'Kim', 'Kim', '100', '600']
# Entities: ['Lizzy', 'the night', 'Tom', 'every day', 'One day', 'Tom', 'second']
# Entities: ['Beth', 'Beth', 'Joe', 'Allie', 'One day']
# Entities: ['Fannie', 'Fannie', 'Joe', 'Joe']
# Entities: ['Alan', 'Alan', 'Rob', '100', 'first', 'Rob']
# Entities: ['a thousand quarters', 'Anna', 'the morning', 'the end of the day', 'more than ten']
# Entities: ['Savannah', 'Jake', 'Jake']
# Entities: ['Jerry', 'Tina', 'Tina', 'an hour']
# Entities: ['Jane', 'one night', 'The next day', 'Chandler', 'England']
# Entities: ['Martha', 'today', 'today', 'a great day']
# Entities: ['Bernie', 'Bernie', 'Hillary', 'Bob', 'Kim', 'Kim', 'Bob', 'Kim']
# Entities: ['Libby', 'most days', 'the day', 'today', '2 year - old', 'today', 'Siena']
# Entities: ['5 minute', '1300', '1175', 'four month old', 'Santa', 'Christmas', 'Timmy', 'Santa']
# Entities: ['Mike', 'Mike']
# Entities: ['2004', 'Tom', 'first', 'first', 'Tom']
# Entities: ['Belinda', 'Bill']
# Entities: ['John', 'John', 'John', 'John', 'John']
# Entities: ['Spanish', 'Venezuela', 'USA', 'Skype', 'almost a year', 'USA', 'First', 'first']
# Entities: ['Marie', 'the first day']
# Entities: ['a week', 'Amy', 'Mary', 'One day', 'two', 'Mary']
# Entities: ['Tom', 'Tom', 'Shelly', 'four years old']
# Entities: ['Tom', 'Tom', 'Tom', 'Tom', 'Chihuahua', 'Mike', 'Mike', 'Mike', 'Mike', 'Mike']
# Entities: ['Sam']
# Entities: ['Tony Tortellini', 'muslims', 'Mahmoud', 'muslims', 'Mike', 'One day']
# Entities: ['Sam', 'Amy', 'a week ago', 'all night']
# Entities: ['Bevin', 'Tim', 'Tim']
# Entities: ['John', 'earlier this year', 'Tom', 'Tom']
# Entities: ['one night', 'One day']
# Entities: ['Caroline', 'Joe', 'first', 'Today', 'Kim', 'Kim']
# Entities: ['today', 'an hour', 'Edward', 'One day', 'Audi', 'many hours', 'Aaron']
# Entities: ['Tyler', 'first', 'Rosemary', 'almost ten years']
# Entities: ['Jen', 'all day', 'Sally', 'Tokyo', 'Japanese']
# Entities: ['Kate', 'two', 'Jack', 'Jack', 'weeks', 'weeks', 'Jack']
# Entities: ['Susie', 'every day', 'One', 'Susie', 'John', 'John', 'all spring', 'John']
# Entities: ['John', '8th', 'John', 'next year', 'John', 'John', 'Electronica', 'Electronica', 'months', 'Erika']
# Entities: ['Monique', 'Gary', 'Monique']
# Entities: ['Tom', 'Tom']
# Entities: ['Manuel', 'Alice', 'Christmas']
# Entities: ['Ray', 'Billy', 'Billy', 'Billy']
# Entities: ['Jen', 'Halfway', 'Mary', 'Mary', 'Florida', 'Mary', 'thousand']
# Entities: ['a few hours']
# Entities: ['Tony', 'Tony', 'One day', 'The next morning']
# Entities: ['Michael', 'Tina', 'hundreds', 'Tina']
# Entities: ['Jill', 'Tom', 'four year old', 'Tom', 'the night']
# Entities: ['California', 'Tom', 'Tom']
# Entities: ['One day', 'Timmy', 'Froggy', 'one hundred burgers', 'Dora']
# Entities: ['Bob', 'a few months', 'Bobby', 'Bobby', 'Tim', 'two', 'weeks', 'Tim']
# Entities: ['Anna', 'Anna', 'Carlos', 'Carlos']
# Entities: ['Milton', 'One day', 'Sam', 'Sam', 'seven']
# Entities: ['Gina', 'Kate']
# Entities: ['Bill', 'Arizona', 'first', '50 years', 'ten years', 'fifty year', '2 year old', 'two', '7', 'One day', 'Sanbucks']
# Entities: ['Cici', 'years', 'a week later', 'Ford', 'Anita']
# Entities: ['Jeff', 'One day', 'Bill']
# Entities: ['Andy', 'Andy', 'Andy', 'One day', 'Two years later', 'Andy']
# Entities: ['Dina', 'one', 'two', 'Dina', '8th', 'OfT']
# Entities: ['Tom', 'one', 'Tom', 'Tom', 'Sally', 'Sally', 'Sally', 'Sally', 'Sally']
# Entities: ['Mark', 'Mark', 'Tom', 'Tom']
# Entities: ['Carl', 'Carl', 'Carl', 'Tom', 'Tom']
# Entities: ['Every day of the week', '8 weeks', 'three hours', 'Abby', 'Dan', 'Abby', 'Texas', 'Dan', 'Abby', 'Dan', 'Abby', 'Abby', 'Dan', 'Abby', 'Dan']
# Entities: []
# Entities: ['last week', 'The day', 'four']
# Entities: ['Leticia', 'first day', 'that night', 'last night', 'Sue']
# Entities: ['Kevin', 'One day', 'Kevin', 'Jason', 'Jason', 'Jason', 'Jason']
# Entities: ['Jill', 'three', 'One day', 'Berkeley', 'every day', 'Carrie']
# Entities: ['Anna', 'all week', 'Anna', 'only one']
# Entities: ['Tasha', 'Tasha', 'Thomas', 'fifth', 'Thompson']
# Entities: ['Ellen', 'Ellen', 'Ellen', 'five hundred dollars', 'Ellen', 'Tim', 'Tim', 'Tim', 'every day', 'three months', 'Tim', 'Tim', 'third']
# Entities: ['Tory', 'Tory', 'the spring this winter', 'all spring', '100 degrees']
# Entities: ['Liam', 'Ted', 'Liam', 'Ted', 'Liam', 'Ted', 'Jan']
# Entities: ['Allie', 'only five miles', 'Jesus', 'everyday', 'This year', 'Austin', 'one']
# Entities: ['Kate', 'Tom', 'Tom']
# Entities: ['Rick', 'Albion', 'Halfway', 'Albion', 'Nadia']
# Entities: ['Tom', 'Tom', 'Kim', 'Kim', 'Kim']
# Entities: ['Penelope', 'One day', 'Tim', 'West', 'Tim']
# Entities: ['Paul', 'Paul', 'a week', 'Paul', 'Mary', '20', '200 pounds', 'over a month', '20']
# Entities: ['Tom', 'first', 'second', 'all day', 'One day']
# Entities: ['Eliza', 'Kia', 'Kia', 'Kia', 'Kia']
# Entities: ['Katie', 'Joe', 'first day', 'the day', 'Joe', 'Joe']
# Entities: ['Tom', "ten Year's", 'one', 'Amy', 'American']
# Entities: ['Duncan', 'Duncan', 'Tom', 'Tom']
# Entities: ['Susan', 'Susan', 'five', 'Canadian', 'Canadian', 'the end of the week', 'Brewer']
# Entities: ['two', 'his night', 'one', 'Will', 'Will']
# Entities: ['Brad', 'Art', 'Lucy', 'Lucy']
# Entities: ['Dave', 'Hannah']
# Entities: ['Two', 'Portland', 'the next day']
# Entities: ['Kim', 'three', 'an hour']
# Entities: ['Tom', 'Tom', 'Tom', 'Tom', 'Tim', 'fifth', 'Tim']
# Entities: ['Megan', 'Megan', 'Amy', 'Amy', 'Amy']
# Entities: ['Tom', 'One night', 'One day']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-48d7726904e9> in <cell line: 0>()
#      52 light_path = '/content/10000-N=25-len=1.json'
#      53
# ---> 54 full_score = evaluate_dataset(full_path, desc='Full(150k)', allow_partial=True)
#      55 light_score = evaluate_dataset(light_path, desc='Light(10k)', allow_partial=True)
#      56
#
# <ipython-input-4-48d7726904e9> in evaluate_dataset(path, desc, allow_partial)
#      45         context = '. '.join(sents[:4]) + '.'
#      46         gen = item.get('GEN', '')
# ---> 47         scores.append(compute_cohere_score(context, gen, allow_partial))
#      48     return mean(scores)
#      49
#
# <ipython-input-4-48d7726904e9> in compute_cohere_score(context, gen, allow_partial)
#      30
#      31 def compute_cohere_score(context, gen, allow_partial=False):
# ---> 32     doc = nlp(context + " " + gen)
#      33     print(f"Entities: {[ent.text for ent in doc.ents]}")
#      34     grid = build_entity_grid(doc)
#
# /usr/local/lib/python3.11/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1050                 error_handler = proc.get_error_handler()
#    1051             try:
# -> 1052                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1053             except KeyError as e:
#    1054                 # This typically happens if a component is not initialized
#
# /usr/local/lib/python3.11/dist-packages/spacy/pipeline/attributeruler.py in __call__(self, doc)
#     140         error_handler = self.get_error_handler()
#     141         try:
# --> 142             matches = self.match(doc)
#     143             self.set_annotations(doc, matches)
#     144             return doc
#
# /usr/local/lib/python3.11/dist-packages/spacy/pipeline/attributeruler.py in match(self, doc)
#     149         matches = self.matcher(doc, allow_missing=True, as_spans=False)
#     150         # Sort by the attribute ID, so that later rules have precedence
# --> 151         matches = [
#     152             (int(self.vocab.strings[m_id]), m_id, s, e) for m_id, s, e in matches  # type: ignore
#     153         ]
#
# /usr/local/lib/python3.11/dist-packages/spacy/pipeline/attributeruler.py in <listcomp>(.0)
#     150         # Sort by the attribute ID, so that later rules have precedence
#     151         matches = [
# --> 152             (int(self.vocab.strings[m_id]), m_id, s, e) for m_id, s, e in matches  # type: ignore
#     153         ]
#     154         matches.sort()
#
# KeyboardInterrupt:

# %%
#!pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113

# %%
# !git clone https://github.com/facebookresearch/faiss.git
# %cd faiss
# Out:
# Cloning into 'faiss'...
# remote: Enumerating objects: 65322, done.
# remote: Counting objects: 100% (32725/32725), done.
# remote: Compressing objects: 100% (769/769), done.
# remote: Total 65322 (delta 32415), reused 31956 (delta 31956), pack-reused 32597 (from 2)
# Receiving objects: 100% (65322/65322), 229.48 MiB | 33.19 MiB/s, done.
# Resolving deltas: 100% (59748/59748), done.
# /content/faiss

# %%
# !pip install faiss-gpu-cu11
# Out:
# Collecting faiss-gpu-cu11
#   Downloading faiss_gpu_cu11-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu11) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu11) (24.2)
# Collecting nvidia-cuda-runtime-cu11>=11.8.89 (from faiss-gpu-cu11)
#   Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cublas-cu11>=11.11.3.6 (from faiss-gpu-cu11)
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Downloading faiss_gpu_cu11-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 MB 39.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl (417.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl (875 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 58.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cublas-cu11, faiss-gpu-cu11
# Successfully installed faiss-gpu-cu11-1.10.0 nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-runtime-cu11-11.8.89

# %%
#!pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
#!pip uninstall -y tensorflow && pip install tensorflow-cpu -q

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=6be9b253662e72dfb8bc96aafc156b0f10f988d4e9acbb7a239b185b62a84f5c
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
# !pip install evaluate -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.1 MB/s eta 0:00:00

# %%
# !pip install bert-score -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 118.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 100.5 MB/s eta 0:00:00

# %%
import torch
import pandas as pd
import requests
import gc
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm

import json
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer
import evaluate
from torch.nn import CrossEntropyLoss

import numpy as np
from collections import Counter
from transformers import GPT2LMHeadModel, GPT2Tokenizer
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# # tencdm

# %%
# !git clone https://github.com/M0RJIQUE/tencdm.git
# %cd tencdm
# Out:
# Cloning into 'tencdm'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 38 (delta 0), reused 38 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (38/38), 34.70 KiB | 1.33 MiB/s, done.
# /content/faiss/tencdm

# %%
# !pip install -r requirements.txt
# Out:
# Collecting config==0.5.1 (from -r requirements.txt (line 6))
#   Downloading config-0.5.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting datasets==2.16.1 (from -r requirements.txt (line 7))
#   Downloading datasets-2.16.1-py3-none-any.whl.metadata (20 kB)
# Collecting evaluate==0.4.0 (from -r requirements.txt (line 8))
#   Downloading evaluate-0.4.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting huggingface_hub==0.21.4 (from -r requirements.txt (line 9))
#   Downloading huggingface_hub-0.21.4-py3-none-any.whl.metadata (13 kB)
# Collecting ml_collections==0.1.1 (from -r requirements.txt (line 10))
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting nltk==3.8.1 (from -r requirements.txt (line 11))
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting numpy==1.24.3 (from -r requirements.txt (line 12))
#   Downloading numpy-1.24.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting spacy==3.7.2 (from -r requirements.txt (line 13))
#   Downloading spacy-3.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting timm==0.6.13 (from -r requirements.txt (line 14))
#   Downloading timm-0.6.13-py3-none-any.whl.metadata (38 kB)
# Collecting torch==2.4.0 (from -r requirements.txt (line 15))
#   Downloading torch-2.4.0-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting tqdm==4.65.0 (from -r requirements.txt (line 16))
#   Downloading tqdm-4.65.0-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 367.3 kB/s eta 0:00:00
# Collecting transformers==4.37.0 (from -r requirements.txt (line 17))
#   Downloading transformers-4.37.0-py3-none-any.whl.metadata (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 6.3 MB/s eta 0:00:00
# Collecting wandb==0.15.0 (from -r requirements.txt (line 18))
#   Downloading wandb-0.15.0-py3-none-any.whl.metadata (8.0 kB)
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement faiss-gpu==1.7.2 (from versions: none)
# ERROR: No matching distribution found for faiss-gpu==1.7.2

# %%
# !pip install faiss-gpu
# Out:
# ERROR: Could not find a version that satisfies the requirement faiss-gpu (from versions: none)
# ERROR: No matching distribution found for faiss-gpu

# %%
# !pip install ml_collections -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.6 MB/s eta 0:00:00

# %%
# !pip install datasets -q
from datasets import load_dataset, Dataset, DatasetDict, concatenate_datasets

# %%
# !python -m data.load --dataset_name='rocstories'
# Out:
# roc_stories.py: 100% 6.51k/6.51k [00:00<00:00, 33.8MB/s]
# dataset_infos.json: 100% 1.33k/1.33k [00:00<00:00, 9.34MB/s]
# The repository for wza/roc_stories contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/wza/roc_stories.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# ROCStories__spring2016.csv: 100% 13.1M/13.1M [00:00<00:00, 48.3MB/s]
# ROCStories_winter2017.csv: 100% 14.5M/14.5M [00:00<00:00, 78.5MB/s]
# Generating train split: 98161 examples [00:09, 10030.80 examples/s]
# Loading... (num_proc=30): 100% 98161/98161 [00:00<00:00, 262269.74 examples/s]
# Saving the dataset (1/1 shards): 100% 88161/88161 [00:00<00:00, 311551.85 examples/s]
# Saving the dataset (1/1 shards): 100% 10000/10000 [00:00<00:00, 268903.56 examples/s]

# %%
# !python -m data.make_statistics --dataset_name='rocstories' --encoder_name='roberta-base'
# Out:
# 2025-03-16 10:14:02.337973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742120042.360251    1737 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742120042.366911    1737 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 100% 570/570 [00:00<00:00, 4.28MB/s]
# config.json: 100% 570/570 [00:00<00:00, 4.48MB/s]
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 337kB/s]
# vocab.txt: 100% 213k/213k [00:00<00:00, 6.47MB/s]
# tokenizer.json: 100% 436k/436k [00:00<00:00, 4.75MB/s]
# model.safetensors: 100% 436M/436M [00:03<00:00, 133MB/s]
# Dataset preprocessing (num_proc=30): 100% 88161/88161 [00:05<00:00, 16766.84 examples/s]
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 20 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# mean: ['0.098', '0.096', '-0.118'], std2: ['0.356', '0.337', '0.340']: 100% 345/345 [01:15<00:00,  4.55it/s]

# %%
# !python -m model.train_decoder --dataset_name='rocstories' --encoder_name='roberta-base'
# Out:
# 2025-03-16 10:15:44.725824: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742120144.747152    2411 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742120144.753705    2411 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sasha-sidorkina (sasha-sidorkina-hse) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.8
# wandb: Run data is saved locally in /content/faiss/tencdm/wandb/run-20250316_101556-dfrjch4n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run decoder-roberta-base-128-transformer
# wandb: ⭐️ View project at https://wandb.ai/sasha-sidorkina-hse/test
# wandb: 🚀 View run at https://wandb.ai/sasha-sidorkina-hse/test/runs/dfrjch4n
# Num params: 43561540
# Dataset preprocessing (num_proc=30): 100% 88161/88161 [00:05<00:00, 16942.43 examples/s]
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 30 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Dataset preprocessing (num_proc=30): 100% 10000/10000 [00:00<00:00, 11275.56 examples/s]
#   0% 0/1378 [00:00<?, ?it/s]/content/faiss/tencdm/model/train_decoder.py:86: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   t = torch.cuda.FloatTensor(latent.shape[0]).uniform_() * (config.decoder.T - config.decoder.eps) + config.decoder.eps
# 100% 1378/1378 [01:25<00:00, 16.11it/s]
# 100% 157/157 [00:06<00:00, 23.57it/s]
# Save model to: /content/faiss/tencdm/datasets/rocstories/decoder-roberta-base-128-transformer.pth
# wandb:
# wandb: 🚀 View run decoder-roberta-base-128-transformer at: https://wandb.ai/sasha-sidorkina-hse/test/runs/dfrjch4n
# wandb: Find logs at: wandb/run-20250316_101556-dfrjch4n/logs

# %%
# !torchrun --nproc_per_node=1 train_diffusion.py --dataset_name='rocstories' --encoder_name='roberta-base'
# Out:
# Streaming output truncated to the last 5000 lines.
# Dataset preprocessing (num_proc=30):  73% 64657/88161 [00:06<00:02, 10924.61 examples/s]
# Dataset preprocessing (num_proc=30):  77% 67595/88161 [00:06<00:01, 10889.52 examples/s]
# Dataset preprocessing (num_proc=30):  80% 70533/88161 [00:06<00:01, 10890.62 examples/s]
# Dataset preprocessing (num_proc=30):  83% 73471/88161 [00:06<00:01, 10953.89 examples/s]
# Dataset preprocessing (num_proc=30):  87% 76409/88161 [00:07<00:01, 10907.09 examples/s]
# Dataset preprocessing (num_proc=30):  90% 79347/88161 [00:07<00:00, 10972.57 examples/s]
# Dataset preprocessing (num_proc=30):  93% 82285/88161 [00:07<00:00, 10956.17 examples/s]
# Dataset preprocessing (num_proc=30):  97% 85223/88161 [00:08<00:00, 10968.34 examples/s]
# Dataset preprocessing (num_proc=30): 100% 88161/88161 [00:08<00:00, 10416.86 examples/s]
# Dataset length: 88161
# loss_x_0: 0.4475, grad_norm: 0.1323, :  74% 148433/200000 [17:13:43<4:23:53,  3.26it/s]
# Dataset preprocessing (num_proc=30):   0% 0/88161 [00:00<?, ? examples/s]
# Dataset preprocessing (num_proc=30):   3% 2939/88161 [00:00<00:13, 6301.11 examples/s]
# Dataset preprocessing (num_proc=30):   7% 5878/88161 [00:00<00:10, 8175.39 examples/s]
# Dataset preprocessing (num_proc=30):  10% 8817/88161 [00:01<00:08, 8951.70 examples/s]
# Dataset preprocessing (num_proc=30):  13% 11756/88161 [00:01<00:07, 9618.29 examples/s]
# Dataset preprocessing (num_proc=30):  17% 14695/88161 [00:01<00:07, 10089.19 examples/s]
# Dataset preprocessing (num_proc=30):  20% 17634/88161 [00:01<00:06, 10373.43 examples/s]
# Dataset preprocessing (num_proc=30):  23% 20573/88161 [00:02<00:06, 10242.85 examples/s]
# Dataset preprocessing (num_proc=30):  27% 23512/88161 [00:02<00:06, 10465.17 examples/s]
# Dataset preprocessing (num_proc=30):  30% 26451/88161 [00:02<00:05, 10712.74 examples/s]
# Dataset preprocessing (num_proc=30):  33% 29390/88161 [00:02<00:05, 10822.96 examples/s]
# Dataset preprocessing (num_proc=30):  37% 32329/88161 [00:03<00:05, 10949.59 examples/s]
# Dataset preprocessing (num_proc=30):  40% 35268/88161 [00:03<00:04, 10953.58 examples/s]
# Dataset preprocessing (num_proc=30):  43% 38207/88161 [00:03<00:04, 11057.39 examples/s]
# Dataset preprocessing (num_proc=30):  47% 41146/88161 [00:03<00:04, 11123.71 examples/s]
# Dataset preprocessing (num_proc=30):  50% 44085/88161 [00:04<00:04, 10962.96 examples/s]
# Dataset preprocessing (num_proc=30):  60% 52902/88161 [00:05<00:03, 11024.45 examples/s]
# Dataset preprocessing (num_proc=30):  63% 55841/88161 [00:05<00:02, 11080.31 examples/s]
# Dataset preprocessing (num_proc=30):  67% 58780/88161 [00:05<00:02, 11089.83 examples/s]
# Dataset preprocessing (num_proc=30):  70% 61719/88161 [00:05<00:02, 11063.93 examples/s]
# Dataset preprocessing (num_proc=30):  73% 64657/88161 [00:06<00:02, 11080.09 examples/s]
# Dataset preprocessing (num_proc=30):  77% 67595/88161 [00:06<00:01, 11125.44 examples/s]
# Dataset preprocessing (num_proc=30):  80% 70533/88161 [00:06<00:01, 11058.87 examples/s]
# Dataset preprocessing (num_proc=30):  83% 73471/88161 [00:06<00:01, 11038.57 examples/s]
# Dataset preprocessing (num_proc=30):  87% 76409/88161 [00:07<00:01, 11113.58 examples/s]
# Dataset preprocessing (num_proc=30):  90% 79347/88161 [00:07<00:00, 11044.53 examples/s]
# Dataset preprocessing (num_proc=30):  93% 82285/88161 [00:07<00:00, 11082.99 examples/s]
# Dataset preprocessing (num_proc=30):  97% 85223/88161 [00:07<00:00, 11141.64 examples/s]
# Dataset preprocessing (num_proc=30): 100% 88161/88161 [00:08<00:00, 10551.20 examples/s]
# Dataset length: 88161
# loss_x_0: 0.4753, grad_norm: 0.1155, :  79% 158294/200000 [18:30:33<3:56:36,  2.94it/s]
# Dataset preprocessing (num_proc=30):   0% 0/88161 [00:00<?, ? examples/s]
# Dataset preprocessing (num_proc=30):   3% 2939/88161 [00:00<00:13, 6414.37 examples/s]
# Dataset preprocessing (num_proc=30):   7% 5878/88161 [00:00<00:09, 8348.28 examples/s]
# Dataset preprocessing (num_proc=30):  10% 8817/88161 [00:01<00:08, 9218.34 examples/s]
# Dataset preprocessing (num_proc=30):  13% 11756/88161 [00:01<00:07, 9739.79 examples/s]
# Dataset preprocessing (num_proc=30):  17% 14695/88161 [00:01<00:07, 9833.43 examples/s]
# Dataset preprocessing (num_proc=30):  20% 17634/88161 [00:01<00:06, 10077.93 examples/s]
# Dataset preprocessing (num_proc=30):  23% 20573/88161 [00:02<00:06, 10387.43 examples/s]
# Dataset preprocessing (num_proc=30):  27% 23512/88161 [00:02<00:06, 10553.27 examples/s]
# Dataset preprocessing (num_proc=30):  30% 26451/88161 [00:02<00:05, 10720.90 examples/s]
# Dataset preprocessing (num_proc=30):  33% 29390/88161 [00:02<00:05, 10800.95 examples/s]
# Dataset preprocessing (num_proc=30):  37% 32329/88161 [00:03<00:05, 10844.58 examples/s]
# Dataset preprocessing (num_proc=30):  40% 35268/88161 [00:03<00:04, 10886.15 examples/s]

# %%
#import torch
#from transformers import T5ForConditionalGeneration, T5Tokenizer

#model_path = "/content/tencdm/datasets/rocstories/decoder-t5-base-128-transformer.pth"
#tokenizer_name = "t5-base"

#tokenizer = T5Tokenizer.from_pretrained(tokenizer_name)

#model = T5ForConditionalGeneration.from_pretrained(tokenizer_name)

#state_dict = torch.load(model_path, map_location="cpu")

#new_state_dict = {}
#for key, value in state_dict.items():
#    if key.startswith("module."):
#        key = key[len("module."):]
#    new_state_dict[key] = value

#model.load_state_dict(new_state_dict, strict=False)

#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#model.to(device)
#model.eval()

#print("Урааааа")

# %%
tokenizer = AutoTokenizer.from_pretrained("google-t5/t5-base")
#model = AutoModel.from_pretrained('/content/tencdm/datasets/rocstories/decoder-t5-base-128-transformer.pth').to(device)

# %%
model = '/content/tencdm/datasets/rocstories/decoder-t5-base-128-transformer.pth'

# %%
def download_csv(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, "wb") as f:
            f.write(response.content)
        print(f"Файл сохранен: {filename}")
    else:
        print(f"Ошибка загрузки {url}: {response.status_code}")

# %%
def calculate_perplexity(logits, inputs):
    shift_logits = logits[..., :-1, :].contiguous()
    shift_labels = inputs["input_ids"][..., 1:].contiguous()
    loss_fct = torch.nn.CrossEntropyLoss(reduction="none")
    loss = loss_fct(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))
    loss = loss.view(shift_labels.size()).mean(dim=1)
    return torch.exp(loss).cpu().tolist()

# %%
import pandas as pd
import torch
import gc
from tqdm import tqdm

def evaluate_model(filepath, batch_size=4, is_test=False):
    df = pd.read_csv(filepath)
    correct = 0
    total = len(df)
    total_perplexity = 0
    rank_correct = 0

    with tqdm(total=len(df), desc="Оценка модели", unit="примеров") as pbar:
        for i in range(0, len(df), batch_size):
            batch = df.iloc[i : i + batch_size]

            contexts = [
                f"{row['InputSentence3']} {row['InputSentence4']}" for _, row in batch.iterrows()
            ]
            endings1 = [row['RandomFifthSentenceQuiz1'] for _, row in batch.iterrows()]
            endings2 = [row['RandomFifthSentenceQuiz2'] for _, row in batch.iterrows()]

            inputs1 = tokenizer(contexts, endings1, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)
            inputs2 = tokenizer(contexts, endings2, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)

            with torch.no_grad():
                logits1 = model(input_ids=inputs1["input_ids"], attention_mask=inputs1["attention_mask"], decoder_input_ids=inputs1["input_ids"]).logits
                logits2 = model(input_ids=inputs2["input_ids"], attention_mask=inputs2["attention_mask"], decoder_input_ids=inputs2["input_ids"]).logits

            perplexity1 = calculate_perplexity(logits1, inputs1)
            perplexity2 = calculate_perplexity(logits2, inputs2)

            for j, row in enumerate(batch.itertuples()):
                if not is_test:
                    correct_answer = getattr(row, "AnswerRightEnding", None)
                    if correct_answer is None:
                        raise ValueError("Поле AnswerRightEnding отсутствует в DataFrame")

                    pred = 1 if perplexity1[j] < perplexity2[j] else 2
                    if pred == correct_answer:
                        correct += 1
                    total_perplexity += perplexity1[j] if correct_answer == 1 else perplexity2[j]

                    if (correct_answer == 1 and perplexity1[j] < perplexity2[j]) or \
                    (correct_answer == 2 and perplexity2[j] < perplexity1[j]):
                        rank_correct += 1

            del inputs1, inputs2, logits1, logits2
            torch.cuda.empty_cache()
            gc.collect()

            pbar.update(len(batch))

    if not is_test:
        accuracy = correct / total * 100
        avg_perplexity = total_perplexity / total
        rank_accuracy = rank_correct / total * 100

        print(f"Точность (Accuracy): {accuracy:.2f}%")
        print(f"Средняя перплексия (Perplexity): {avg_perplexity:.2f}")
        print(f"Rank Accuracy: {rank_accuracy:.2f}%")
    else:
        print(f"Обработка тестового набора завершена. Всего примеров: {total}")

# %%
VAL_URL = "https://goo.gl/XWjas1"
TEST_URL = "https://goo.gl/BcTtB4"

# %%
download_csv(VAL_URL, "val_set.csv")
download_csv(TEST_URL, "test_set.csv")
# Out:
# Файл сохранен: val_set.csv
# Файл сохранен: test_set.csv

# %%
if __name__ == "__main__":
    print("Оценка на валидационном наборе:")
    evaluate_model("val_set.csv")

    print("Оценка на тестовом наборе:")
    evaluate_model("test_set.csv", is_test=True)
# Out:
# Оценка на валидационном наборе:
# Оценка модели:   0%|          | 0/1571 [00:00<?, ?примеров/s]Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Оценка модели: 100%|██████████| 1571/1571 [02:38<00:00,  9.93примеров/s]
# Точность (Accuracy): 49.40%
# Средняя перплексия (Perplexity): 97601.31
# Rank Accuracy: 49.40%
# Оценка на тестовом наборе:
# Оценка модели: 100%|██████████| 1571/1571 [02:37<00:00,  9.96примеров/s]
# Обработка тестового набора завершена. Всего примеров: 1571

# %% [markdown]
# # gpt-3.5

# %%
#from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
#tokenizer = AutoTokenizer.from_pretrained("ai-forever/ruGPT-3.5-13B")
#model = AutoModelForCausalLM.from_pretrained("ai-forever/ruGPT-3.5-13B").to(device)

# %%
#from transformers import AutoTokenizer, AutoModelForCausalLM

#tokenizer = AutoTokenizer.from_pretrained("jondurbin/airoboros-gpt-3.5-turbo-100k-7b")
#model = AutoModelForCausalLM.from_pretrained("jondurbin/airoboros-gpt-3.5-turbo-100k-7b")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("ai-forever/rugpt3medium_based_on_gpt2")
model = AutoModelForCausalLM.from_pretrained("ai-forever/rugpt3medium_based_on_gpt2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.61M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/574 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/761 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.73G [00:00<?, ?B/s]

# %%
model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/1.73G [00:00<?, ?B/s]
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1024)
#     (wpe): Embedding(2048, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=3072, nx=1024)
#           (c_proj): Conv1D(nf=1024, nx=1024)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=4096, nx=1024)
#           (c_proj): Conv1D(nf=1024, nx=4096)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50257, bias=False)
# )

# %%
def download_csv(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, "wb") as f:
            f.write(response.content)
        print(f"Файл сохранен: {filename}")
    else:
        print(f"Ошибка загрузки {url}: {response.status_code}")

# %%
def calculate_perplexity(logits, inputs):
    shift_logits = logits[..., :-1, :].contiguous()
    shift_labels = inputs["input_ids"][..., 1:].contiguous()
    loss_fct = torch.nn.CrossEntropyLoss(reduction="none")
    loss = loss_fct(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))
    loss = loss.view(shift_labels.size()).mean(dim=1)
    return torch.exp(loss).cpu().tolist()

# %%
def evaluate_model(filepath, batch_size=4, is_test=False):
    df = pd.read_csv(filepath)
    correct = 0
    total = len(df)
    total_perplexity = 0
    rank_correct = 0

    with tqdm(total=len(df), desc="Оценка модели", unit="примеров") as pbar:
        for i in range(0, len(df), batch_size):
            batch = df.iloc[i : i + batch_size]

            contexts = [
                f"{row['InputSentence3']} {row['InputSentence4']}" for _, row in batch.iterrows()
            ]
            endings1 = [row['RandomFifthSentenceQuiz1'] for _, row in batch.iterrows()]
            endings2 = [row['RandomFifthSentenceQuiz2'] for _, row in batch.iterrows()]

            inputs1 = tokenizer(contexts, endings1, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)
            inputs2 = tokenizer(contexts, endings2, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)

            with torch.no_grad():
                logits1 = model(input_ids=inputs1["input_ids"], attention_mask=inputs1["attention_mask"], decoder_input_ids=inputs1["input_ids"]).logits
                logits2 = model(input_ids=inputs2["input_ids"], attention_mask=inputs2["attention_mask"], decoder_input_ids=inputs2["input_ids"]).logits

            perplexity1 = calculate_perplexity(logits1, inputs1)
            perplexity2 = calculate_perplexity(logits2, inputs2)

            for j, row in enumerate(batch.itertuples()):
                if not is_test:
                    correct_answer = getattr(row, "AnswerRightEnding", None)
                    if correct_answer is None:
                        raise ValueError("Поле AnswerRightEnding отсутствует в DataFrame")

                    pred = 1 if perplexity1[j] < perplexity2[j] else 2
                    if pred == correct_answer:
                        correct += 1
                    total_perplexity += perplexity1[j] if correct_answer == 1 else perplexity2[j]

                    if (correct_answer == 1 and perplexity1[j] < perplexity2[j]) or \
                    (correct_answer == 2 and perplexity2[j] < perplexity1[j]):
                        rank_correct += 1

            del inputs1, inputs2, logits1, logits2
            torch.cuda.empty_cache()
            gc.collect()

            pbar.update(len(batch))

    if not is_test:
        accuracy = correct / total * 100
        avg_perplexity = total_perplexity / total
        rank_accuracy = rank_correct / total * 100

        print(f"Точность (Accuracy): {accuracy:.2f}%")
        print(f"Средняя перплексия (Perplexity): {avg_perplexity:.2f}")
        print(f"Rank Accuracy: {rank_accuracy:.2f}%")
    else:
        print(f"Обработка тестового набора завершена. Всего примеров: {total}")

VAL_URL = "https://goo.gl/XWjas1"
TEST_URL = "https://goo.gl/BcTtB4"

download_csv(VAL_URL, "val_set.csv")
download_csv(TEST_URL, "test_set.csv")

if __name__ == "__main__":
    print("Оценка на валидационном наборе:")
    evaluate_model("val_set.csv")

    print("Оценка на тестовом наборе:")
    evaluate_model("test_set.csv", is_test=True)
# Out:
# Файл сохранен: val_set.csv
# Файл сохранен: test_set.csv
# Оценка на валидационном наборе:
# Оценка модели: 100%|██████████| 1571/1571 [02:21<00:00, 11.07примеров/s]
# Точность (Accuracy): 53.60%
# Средняя перплексия (Perplexity): 261025.30
# Rank Accuracy: 53.60%
# Оценка на тестовом наборе:
# Оценка модели: 100%|██████████| 1571/1571 [02:23<00:00, 10.96примеров/s]
# Обработка тестового набора завершена. Всего примеров: 1571

# %% [markdown]
# # BLEU ROUGE

# %%
file_path = "/content/150000-N=50-len=1.json"
with open(file_path, "r") as f:
    data = json.load(f)["rocstories"]

# %%
def compute_metrics(gen_texts, ref_texts):
    bleu_scores = []
    rouge_1_scores = []
    rouge_2_scores = []
    rouge_l_scores = []

    scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
    smooth = SmoothingFunction().method1

    for gen, ref in zip(gen_texts, ref_texts):
        bleu = sentence_bleu([ref.split()], gen.split(), smoothing_function=smooth)
        bleu_scores.append(bleu)

        rouge_scores = scorer.score(gen, ref)
        rouge_1_scores.append(rouge_scores["rouge1"].fmeasure)
        rouge_2_scores.append(rouge_scores["rouge2"].fmeasure)
        rouge_l_scores.append(rouge_scores["rougeL"].fmeasure)

    return {
        "BLEU": sum(bleu_scores) / len(bleu_scores),
        "ROUGE-1": sum(rouge_1_scores) / len(rouge_1_scores),
        "ROUGE-2": sum(rouge_2_scores) / len(rouge_2_scores),
        "ROUGE-L": sum(rouge_l_scores) / len(rouge_l_scores),
    }

# %%
generated_texts = [entry["GEN"] for entry in data]
reference_texts = [entry["TRG"] for entry in data]

# %%
metrics = compute_metrics(generated_texts, reference_texts)

# %%
print("BLEU:", round(metrics["BLEU"], 4))
print("ROUGE-1:", round(metrics["ROUGE-1"], 4))
print("ROUGE-2:", round(metrics["ROUGE-2"], 4))
print("ROUGE-L:", round(metrics["ROUGE-L"], 4))
# Out:
# BLEU: 0.0079
# ROUGE-1: 0.1703
# ROUGE-2: 0.0111
# ROUGE-L: 0.1176

# %%
from bert_score import score

P, R, F1 = score(generated_texts, reference_texts, lang="en", model_type="bert-base-uncased")
print("BERTScore F1:", F1.mean().item())
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BERTScore F1: 0.47817757725715637

# %%
smooth = SmoothingFunction().method1
self_bleu_scores = []

for i, gen_text in enumerate(generated_texts[:1000]):
    refs = generated_texts[:i] + generated_texts[i+1:]
    score = sentence_bleu([r.split() for r in refs[:100]], gen_text.split(), smoothing_function=smooth)
    self_bleu_scores.append(score)

self_bleu = np.mean(self_bleu_scores)

# %%
def distinct_n(texts, n):
    ngrams = [tuple(text[i:i+n]) for text in texts for i in range(len(text)-n+1)]
    return len(set(ngrams)) / len(ngrams) if ngrams else 0

tokenized_texts = [nltk.word_tokenize(text.lower()) for text in generated_texts]
distinct_1 = distinct_n(tokenized_texts, 1)
distinct_2 = distinct_n(tokenized_texts, 2)

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
model.eval()

def calculate_ppl(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512).to(device)
    with torch.no_grad():
        outputs = model(**inputs, labels=inputs["input_ids"])
    loss = outputs.loss.item()
    return np.exp(loss)

ppl_scores = [calculate_ppl(text) for text in generated_texts[:100]]
avg_ppl = np.mean(ppl_scores)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.

# %%
print(f"Self-BLEU: {self_bleu:.4f}")
print(f"Distinct-1: {distinct_1:.4f}")
print(f"Distinct-2: {distinct_2:.4f}")
print(f"Perplexity: {avg_ppl:.4f}")
# Out:
# Self-BLEU: 0.1010
# Distinct-1: 0.0290
# Distinct-2: 0.2422
# Perplexity: 33.6940
